# %% [markdown]
# # Carrega arquivos mensais de Licitações da Classe 7010

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import datetime
from dateutil.relativedelta import *
from datetime import date
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
import pandas as pd2

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)

sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()

arquivos=69
datainicio= date(2022,8,1)
print(datainicio)

vtabela='licitacoes'
vtabelasiasg='licitacoes'
while(arquivos>0):
    nomearq = '.\json\\licitacoes\\' + vtabela + datainicio.strftime("%Y-%m")+'.json'
    print(nomearq)
    try: 
        with open(nomearq, encoding="utf8") as json_file:
            data_json = json.loads(json_file.read())
    except:
        print("Erro na abertura do arquivo"+nomearq)
    try: 
        embedded = data_json["_embedded"]
        tb= embedded[vtabelasiasg]
    except:
        print("Erro na preparação do "+nomearq)
    try: 
        df = pd2.DataFrame.from_dict(tb, orient='columns')
        del df['_links']
        if 'numero_item_licitacao' in df.columns:
           del df['numero_item_licitacao']
        if 'codigo_do_item_no_catalogo' in df.columns:
           del df['codigo_do_item_no_catalogo']
    except:
        print("Erro na leitura do "+nomearq)
    df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate) 
    datainicio = datainicio - relativedelta(months=1)
    print(datainicio)
    arquivos=arquivos-1

# %% [markdown]
# # Carga de Itens da licitação

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import datetime
from dateutil.relativedelta import *
from datetime import date
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
import pandas as pd2

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)

sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()

# specify your path of directory
path = ".\\json\\itens"

vtabela='licitacoes'
frame = pd.read_sql('select * from '+vtabela, dbConnection);
query='select count(*) from '+vtabela
try:
    numero = pd.read_sql(query,dbConnection)
    n=numero['count(*)'][0]
except:
    n=0
print(n)
reg=2040
while reg<n:
        nomearq='itens'+frame['identificador'][reg]+'.json'
        url = 'http://compras.dados.gov.br/licitacoes/id/licitacao/'+frame['identificador'][reg]+'/itens.json'
        try:
            response = urlopen(url)
            data_json = json.loads(response.read())
            with open(path+"\\"+nomearq,'w') as f:
                json.dump(data_json,f)
        except HTTPError as e:
            print(e.code)
            print(e.read()) 
        except URLError as u:
             print('Erro de URL')
        reg += 1
        print(reg)

# %% [markdown]
# # Carga de pregões

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import datetime
from dateutil.relativedelta import *
from datetime import date
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
import pandas as pd2

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)

sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()

# specify your path of directory
path = ".\\json\\pregoes"

vtabela='licitacoes'
frame = pd.read_sql('select * from '+vtabela, dbConnection);
query='select count(*) from '+vtabela
try:
    numero = pd.read_sql(query,dbConnection)
    n=numero['count(*)'][0]
except:
    n=0
print(n)
reg=1
while reg<n:
        nomearq='itenspregoes'+frame['identificador'][reg]+'.json'
        url = 'http://compras.dados.gov.br/pregoes/id/pregao/'+frame['identificador'][reg]+'/itens.json'
        print(url)
        try:
            response = urlopen(url)
            data_json = json.loads(response.read())
            with open(path+"\\"+nomearq,'w') as f:
                json.dump(data_json,f)
        except HTTPError as e:
            print(e.code)
            print(e.read()) 
        except URLError as u:
             print('Erro de URL')
        reg += 1
        print(reg)

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import datetime
from dateutil.relativedelta import *
from datetime import date
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
import pandas as pd2

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)

sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()

# specify your path of directory
path = ".\\json\\precospraticados"

vtabela='licitacoes'
frame = pd.read_sql('select * from '+vtabela, dbConnection);
query='select count(*) from '+vtabela
try:
    numero = pd.read_sql(query,dbConnection)
    n=numero['count(*)'][0]
except:
    n=0
print(n)
reg=0
while reg<n:
        nomearq='precospraticados'+frame['identificador'][reg]+'.json'       
        url = 'http://compras.dados.gov.br/licitacoes/id/preco_praticado/'+frame['identificador'][reg]+'/itens.json'
        try:
            response = urlopen(url)
            data_json = json.loads(response.read())
            with open(path+"\\"+nomearq,'w') as f:
                json.dump(data_json,f)
        except HTTPError as e:
            print(e.code)
            print(e.read()) 
        except URLError as u:
             print('Erro de URL')
        reg += 1
        print(reg)

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import datetime
from dateutil.relativedelta import *
from datetime import date
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
import pandas as pd2

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)

sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()

# specify your path of directory
path = ".\\json\\precospraticados"

vtabela='licitacoes'
frame = pd.read_sql('select * from '+vtabela, dbConnection);
query='select count(*) from '+vtabela
try:
    numero = pd.read_sql(query,dbConnection)
    n=numero['count(*)'][0]
except:
    n=0
print(n)
reg=0
while reg<n:
        nomearq='precospraticados'+frame['identificador'][reg]+'.json'       
        url = 'http://compras.dados.gov.br/licitacoes/id/preco_praticado/'+frame['identificador'][reg]+'/itens.json'
        try:
            response = urlopen(url)
            data_json = json.loads(response.read())
            with open(path+"\\"+nomearq,'w') as f:
                json.dump(data_json,f)
        except HTTPError as e:
            print(e.code)
            print(e.read()) 
        except URLError as u:
             print('Erro de URL')
        reg += 1
        print(reg)

# %% [markdown]
# # Carga dos Itens da Licitação

# %%
from sqlalchemy import create_engine
import os
import pymysql
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
import pandas as pd2

vtabela='itensLicitacao'

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)
    
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
 
# specify your path of directory
path = "C:\Workspace-SB\IA-PP-Mestrado\PesqPrecos\ppweb\static\json\material"
 
directories = os.listdir( path )
i=1
for file in directories:
    nomearq=file
    print(str(i)+" "+nomearq)
    try: 
        with open(path+"\\"+nomearq, encoding="utf8") as json_file:
            data_json = json.loads(json_file.read())
    except:
        print("Erro na abertura do arquivo "+nomearq)
    try: 
        embedded = data_json["_embedded"]
        tb= embedded['itensLicitacao']
    except:
        print("Erro na preparação do "+nomearq)
    try: 
        df = pd2.DataFrame.from_dict(tb, orient='columns')
        del df['_links']
    except:
        print("Erro na leitura do "+nomearq)
    try:
        df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate)
    except:
        print("Erro na gravação do arquivo "+nomearq)
    i=i+1

# %% [markdown]
# # Carga dos Preços praticados

# %%
from sqlalchemy import create_engine
import os
import pymysql
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
import pandas as pd2

vtabela='itensPrecoPraticado'

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)
    
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
 
# specify your path of directory
path = ".\\json\\precospraticados"
 
directories = os.listdir( path )
i=1
for file in directories:
    nomearq=file
    print(str(i)+ " - "+nomearq)
    try: 
        with open(path+"\\"+nomearq, encoding="utf8") as json_file:
            data_json = json.loads(json_file.read())
    except:
        print("Erro na abertura do arquivo "+nomearq)
    try: 
        embedded = data_json["_embedded"]
        tb= embedded['itensPrecoPraticado']
    except:
        print("Erro na preparação do "+nomearq)
    try: 
        df = pd2.DataFrame.from_dict(tb, orient='columns')
        if '_links' in df.columns: 
            del df['_links']
    except:
        print("Erro na leitura do "+nomearq)
    try:
        df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate)
    except:
        print("Erro na gravação do arquivo "+nomearq)
    i=i+1

# %% [markdown]
# # Busca de Materiais na API

# %%
# SELECT distinct codigo_item_material FROM siasg.itensLicitacao where !(codigo_item_material is null);
# http://compras.dados.gov.br/materiais/id/material/000227505.json
# str(num).zfill(9) 

from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import datetime
from dateutil.relativedelta import *
from datetime import date
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
import pandas as pd2
import os

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)
print('Comecei')
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()

# specify your path of directory
path = ".\\json\\material"

vtabela='licitacoes'
frame = pd.read_sql('SELECT distinct codigo_item_material FROM siasg.itensLicitacao where codigo_item_material is not null order by codigo_item_material', dbConnection);
print(frame)
for row in frame.codigo_item_material:
        nomearq='material'+str(row).zfill(9)+'.json'
        arquivo=path+"\\"+nomearq
#        if row<150000: continue
        if not (os.path.exists(arquivo)): 
            print('Fazendo '+str(row))
            url = 'http://compras.dados.gov.br/materiais/id/material/'+str(row).zfill(9)+'.json'
            try:
                response = urlopen(url)
                data_json = json.loads(response.read())
                with open(path+"\\"+nomearq,'w') as f:
                    json.dump(data_json,f)
            except HTTPError as e:
                print('Erro'+str(e.code))
            except URLError as u:
                print('Erro de URL')
print('Concluído')

# %% [markdown]
# # Carga dos JSON de Materiais

# %%
from sqlalchemy import create_engine
import os
import pymysql
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
import pandas as pd2

vtabela='materiais'

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)
    
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
 
# specify your path of directory
path = "C:\\Workspace-SB\\IA-PP-Mestrado\\PesqPrecos\\ppweb\\static\\json\\material"
 
directories = os.listdir( path )
i=1
for file in directories:
    nomearq=file
    print(str(i)+ " - "+nomearq)
    try: 
        with open(path+"\\"+nomearq, encoding="utf8") as json_file:
            data_json = json.loads(json_file.read())
    except:
        print("Erro na abertura do arquivo "+nomearq)
    try: 
        tb = data_json
    except:
        print("Erro na preparação do "+nomearq)
    try: 
        df = pd2.DataFrame.from_dict(tb, orient='columns')
        if '_links' in df.columns: 
            del df['_links']
    except:
        print("Erro na leitura do "+nomearq)
    try:
        df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate)
    except:
        print("Erro na gravação do arquivo "+nomearq)
    i=i+1
# Out:
# 1 - material0000019.json
# 2 - material0000035.json
# 3 - material0000043.json
# 4 - material0000051.json
# 5 - material0000060.json
# 6 - material0000078.json
# 7 - material0000086.json
# 8 - material0000094.json
# 9 - material0000116.json
# 10 - material0000124.json
# 11 - material0000132.json
# 12 - material0000140.json
# 13 - material0000159.json
# 14 - material0000167.json
# 15 - material0000175.json
# 16 - material0000183.json
# 17 - material0000191.json
# 18 - material0000205.json
# 19 - material0000213.json
# 20 - material0000221.json
# 21 - material0000230.json
# 22 - material0000248.json
# 23 - material0000256.json
# 24 - material0000264.json
# 25 - material0000272.json
# 26 - material0000280.json
# 27 - material0000299.json
# 28 - material0000302.json
# 29 - material0000310.json
# 30 - material0000329.json
# 31 - material0000337.json
# 32 - material0000345.json
# 33 - material0000353.json
# 34 - material0000361.json
# 35 - material0000370.json
# 36 - material0000396.json
# 37 - material0000426.json
# 38 - material0000434.json
# 39 - material0000442.json
# 40 - material0000450.json
# 41 - material0000469.json
# 42 - material0000477.json
# 43 - material0000485.json
# 44 - material0000493.json
# 45 - material0000507.json
# 46 - material0000523.json
# 47 - material0000540.json
# 48 - material0000558.json
# 49 - material0000566.json
# 50 - material0000574.json
# 51 - material0000590.json
# 52 - material0000604.json
# 53 - material0000612.json
# 3312 - material0474583.json
# 3313 - material0474584.json
# 3314 - material0474585.json
# 3315 - material0474586.json
# 3316 - material0474587.json
# 3317 - material0474588.json
# 3318 - material0474589.json
# 3319 - material0474591.json
# 3320 - material0474593.json
# 3321 - material0474594.json
# 3322 - material0474596.json
# 3323 - material0474598.json
# 3324 - material0474599.json
# 3325 - material0474600.json
# 3326 - material0474601.json
# 3327 - material0474602.json
# 3328 - material0474603.json
# 3329 - material0474604.json
# 3330 - material0474606.json
# 3331 - material0474607.json
# 3332 - material0474608.json
# 3333 - material0474994.json
# 3334 - material0474995.json
# 3335 - material0474996.json
# 3336 - material0474999.json
# 3337 - material0475011.json
# 3338 - material0475721.json
# 3339 - material0476464.json
# 3340 - material0476754.json
# 3341 - material0476755.json
# 3342 - material0476758.json
# 3343 - material0477907.json
# 3344 - material0477908.json
# 3345 - material0479561.json
# 3346 - material0481511.json
# 3347 - material0485191.json
# 3348 - material0485194.json
# 3349 - material0485195.json
# 3350 - material0485227.json
# 3351 - material0485229.json
# 3352 - material0485233.json
# 3353 - material0485645.json
# 3354 - material0485864.json
# 3355 - material0485900.json
# 3356 - material0485923.json
# 3357 - material0485933.json
# 3358 - material0485937.json
# 3359 - material0485952.json
# 3360 - material0485953.json
# 3361 - material0485954.json
# 3362 - material0486732.json
# 3363 - material0486798.json
# 3364 - material0486800.json
# 3365 - material0602161.json
# 3366 - material0602242.json
# 3367 - material0603588.json

# %% [markdown]
# # Carregar PDM e Classe nos itens de preço

# %%
from sqlalchemy import create_engine
import os
import pymysql
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
import pandas as pd2

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)  
    
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()

frame = pd.read_sql('SELECT * FROM siasg.itensPrecoPraticado where !(codigo_item_material is null)', dbConnection);
for index,row in frame.iterrows():
    cod=row['codigo_item_material']
    frame2= pd2.read_sql('SELECT id_classe, id_pdm, descricao from siasg.materiais where codigo='+str(cod),dbConnection)
    if frame2.size>0:
        classe=frame2['id_classe'][0]
        pdm=frame2['id_pdm'][0]
        descricao = frame2['descricao'][0]
    else: 
        classe=0
        pdm=0
        descricao=''
    frame.at[index,'codigo_pdm']=pdm
    frame.at[index,'codigo_classe']=classe
    frame.at[index, 'descricao_material']=descricao
    # ######################  Descritor PDM
    frame2= pd2.read_sql('SELECT descricao from siasg.pdms where codigo='+str(pdm),dbConnection)
    if frame2.size>0:
        descricao = frame2['descricao'][0]
    else: 
        descricao=''   
    frame.at[index, 'descricao_pdm']=descricao
    print(str(index)+' concluído')
frame.to_sql('Bancodeteste', dbConnection, if_exists='append', index=False, method=insert_on_duplicate)

# %% [markdown]
# # Carrega arquivo de licitações diárias

# %%
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import calendar
import json
import os

# specify your path of directory
path = ".\\json\\licitacoes\\diarias"
ano =2022

vtabela='licitacoes'
for mes in range(1, 13):
    udia = calendar.monthrange(ano, mes)[1]
    udia1 = udia+1
    print(udia1)
    for dia in range(1,udia1):
        erro=True
        while erro:
            sdia=str(ano).zfill(4)+'-'+str(mes).zfill(2)+'-'+str(dia).zfill(2)
            sudia=str(ano).zfill(4)+'-'+str(mes).zfill(2)+'-'+str(udia).zfill(2)
            nomearq='licitacoes'+sdia+'d.json'
            arquivo=path+"\\"+nomearq
            #if not (os.path.exists(arquivo)): 
            print('Fazendo '+sdia)
            url = 'http://compras.dados.gov.br/licitacoes/v1/licitacoes.json?data_publicacao='+sdia
            print(url)
            try:
                response = urlopen(url)
                data_json = json.loads(response.read())
                with open(path+"\\"+nomearq,'w') as f:
                    json.dump(data_json,f)
                erro=False
            except HTTPError as e:
                print('Erro'+str(e.code))
            except URLError as u:
                print('Erro de URL')
print('Concluído')

# %% [markdown]
# # Pesquisa Licitações Anuais

# %%
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import calendar
import json
import os

# specify your path of directory
path = ".\\json\\licitacoes\\novo"
ano =2021

vtabela='licitacoes'
inicio=str(ano).zfill(4)+'-01-01'
fim=str(ano).zfill(4)+'-12-31'
nomearq=vtabela+str(ano).zfill(4)+'.json'
arquivo=path+"\\"+nomearq
if not (os.path.exists(arquivo)): 
    print('Fazendo '+nomearq)
    url = 'http://compras.dados.gov.br/licitacoes/v1/licitacoes.json?item_material_classificacao=7010&data_publicacao_min='+inicio+'&data_publicacao_max='+fim
    print(url)
    try:
        response = urlopen(url)
        data_json = json.loads(response.read())
        with open(path+"\\"+nomearq,'w') as f:
            json.dump(data_json,f)
    except HTTPError as e:
        print('Erro'+str(e.code))
    except URLError as u:
        print('Erro de URL')
print('Concluído')

# %% [markdown]
# # Baixar Licitações Mensais

# %%
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import calendar
import json
import os

# specify your path of directory
path = ".\\json\\licitacoes\\todas"
ano =2022

vtabela='licitacoes'
for mes in range(1, 13):
    udia = calendar.monthrange(ano, mes)[1]
    udia1 = udia+1
    print(udia1)
    smes = str(ano).zfill(4)+'-'+str(mes).zfill(2)
    inicio=smes+'-'+str(1).zfill(2)
    fim=smes+'-'+str(udia).zfill(2)
    nomearq='licitacoes'+smes+'m.json'
    arquivo=path+"\\"+nomearq
    if not (os.path.exists(arquivo)): 
        print('Fazendo '+smes)
        url = 'http://compras.dados.gov.br/licitacoes/v1/licitacoes.json?data_publicacao_min='+inicio+'&data_publicacao_max='+fim
        print(url)
        try:
            response = urlopen(url)
            data_json = json.loads(response.read())
            with open(path+"\\"+nomearq,'w') as f:
                json.dump(data_json,f)
        except HTTPError as e:
            print('Erro'+str(e.code))
        except URLError as u:
            print('Erro de URL')
print('Concluído')
# Out:
# 32
# Fazendo 2022-01
# http://compras.dados.gov.br/licitacoes/v1/licitacoes.json?data_publicacao_min=2022-01-01&data_publicacao_max=2022-01-31
# Erro502
# 29
# Fazendo 2022-02
# http://compras.dados.gov.br/licitacoes/v1/licitacoes.json?data_publicacao_min=2022-02-01&data_publicacao_max=2022-02-28
# 32
# Fazendo 2022-03
# http://compras.dados.gov.br/licitacoes/v1/licitacoes.json?data_publicacao_min=2022-03-01&data_publicacao_max=2022-03-31
# 31
# Fazendo 2022-04
# http://compras.dados.gov.br/licitacoes/v1/licitacoes.json?data_publicacao_min=2022-04-01&data_publicacao_max=2022-04-30
# Erro500
# 32
# Fazendo 2022-05
# http://compras.dados.gov.br/licitacoes/v1/licitacoes.json?data_publicacao_min=2022-05-01&data_publicacao_max=2022-05-31
