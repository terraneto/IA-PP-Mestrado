# %% [markdown]
# # ROD nos 10 primeiros
# Teste do SUOD  para comparação e seleção dos integrantes do aplicativo

# %%
import numpy as np
import pandas as pd
import os
from sklearn.metrics import accuracy_score,recall_score
from pyod.utils.data import evaluate_print
import time

# Importa bibliotecas do PyOD com os algoritmos de detecção de anomalias
from pyod.models.inne import INNE
from pyod.models.abod import ABOD
from pyod.models.cblof import CBLOF
from pyod.models.rod import ROD
from pyod.models.knn import KNN
from pyod.models.lof import LOF
from pyod.models.pca import PCA
from pyod.models.sampling import Sampling
from pyod.models.ecod import ECOD
from pyod.models.copod import COPOD
from pyod.models.suod import SUOD
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score

tabelafinal = pd.DataFrame(columns=['material','acuracia','recall','tempo'])
print(tabelafinal)
      
def carrega_material(path,material):
    arquivo = str(material)+".csv"
    csv_path = os.path.join(path,arquivo)
    df = pd.read_csv(csv_path)
    ## Retira os campos que não serão utilizados no treinamento
    df = df.drop(['licitacao_contrato'],axis=1)
    df = df.drop(['id'],axis=1)
    df = df.drop(['data'],axis=1)
    df = df.drop(['catmat_id'],axis=1)
    df = df.drop(['unidade'],axis=1)
    df = df.drop(['valor_total'],axis=1)
    df = df.drop(['municipio_uasg'],axis=1)
    df = df.drop(['municipio_fornecedor'],axis=1)
    return df
# Out:
# Empty DataFrame
# Columns: [material, acuracia, recall, tempo]
# Index: []

# %%
from sqlalchemy import create_engine
import pymysql
from sqlalchemy.dialects.mysql import insert
import pandas as pd
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
itens = pd.read_sql("SELECT * from siasg.itens", dbConnection);

maioresitens = pd.read_sql("SELECT catmat_id, count(*) from siasg.itens where valor_unitario>0 and catmat_id!=0 group by catmat_id order by count(*) desc", dbConnection);

# %% [markdown]
# # Recuperação dos dados a serem utilizados na avaliação

# %%
##Carrega os dados do item
for index, row in maioresitens.iterrows():
    iniciomaterial = time.time()
    catmat = row['catmat_id']
    df=carrega_material(".",catmat)  
    print(catmat)
    # Separação do Label dos dados
    x = df.iloc[:, :-1]
    y = df.iloc[:, -1]
    #if index<2:
    #    continue
    detector_list = [
             INNE(contamination=0.05, n_estimators=50, random_state= 69), 
             ABOD(contamination=0.05, method= 'default', n_neighbors=20),
             CBLOF(contamination=0.05, n_clusters=2),
             KNN(contamination=0.05, leaf_size=10, method='largest', n_neighbors=10),
             LOF(contamination=0.05, leaf_size=1, n_neighbors=34),  
             PCA(contamination=0.05, n_components=3, n_selected_components=1),
             Sampling(contamination=0.05, subset_size=10),
             ECOD(contamination=0.09),
             COPOD(contamination=0.12)
    ]

    # Inicializar o modelo SUOD
    model = ROD(contamination=0.05, parallel_execution=False)

    # Definir a validação cruzada estratificada
    cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=69)

    acuracia=[]
    recall=[]

    # Loop para treinar e testar o modelo
    k=1
    for train_index, test_index in cv.split(x,y):
        iniciofold = time.time()
        print('iniciando treinamento '+str(k))
        X_train, X_test = x.iloc[train_index], x.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Treinar o modelo
        model.fit(X_train)

        # Fazer as previsões
        y_pred = model.predict(X_test)

        # Calcular a acurácia
        acc = accuracy_score(y_test, y_pred)
        print(f'Acurácia: {acc}')
        acuracia.append(acc)

        # Calcular o Recall
        rec = recall_score(y_test, y_pred)
        print(f'Recall: {rec}')
        recall.append(rec)
        fimfold = time.time()
        tempofold = fimfold-iniciofold
        print(tempofold)
        k+=1

    acuracia_media = sum(acuracia) / len(acuracia)
    recall_medio = sum(recall) / len(recall)


    print(f'Acurácia média: {acuracia_media}')
    print(f'Recall médio: {recall_medio}')
    fim = time.time()
    tempo = fim-iniciomaterial
    print(tempo)
    
    # Grava os resultados da avaliação na tabela final
    tabelafinal.loc[len(tabelafinal.index)] = [catmat,acuracia_media,recall_medio,tempo] 
    if index==9:
        break
# Out:
# 104671
# iniciando treinamento 1
# Acurácia: 0.9765822784810126
# Recall: 0.29411764705882354
# 10.304414987564087
# iniciando treinamento 2
# Acurácia: 0.9432489451476793
# Recall: 0.3697478991596639
# 10.77638053894043
# iniciando treinamento 3
# Acurácia: 0.9782700421940929
# Recall: 0.40336134453781514
# 10.775052309036255
# iniciando treinamento 4
# Acurácia: 0.9466244725738396
# Recall: 0.3949579831932773
# 10.146636486053467
# iniciando treinamento 5
# Acurácia: 0.9464021945558134
# Recall: 0.3898305084745763
# 11.103341102600098
# iniciando treinamento 6
# Acurácia: 0.9366955053808821
# Recall: 0.3305084745762712
# 9.997987747192383
# iniciando treinamento 7
# Acurácia: 0.9491453893226419
# Recall: 0.3813559322033898
# 10.893242120742798
# iniciando treinamento 8
# Acurácia: 0.9784764718294999
# Recall: 0.3644067796610169
# 11.916171789169312
# iniciando treinamento 9
# Acurácia: 0.9466132095378772
# Recall: 0.4067796610169492
# 10.725236654281616
# iniciando treinamento 10
# Acurácia: 0.9398607301118379
# Recall: 0.3445378151260504
# 11.028255939483643
# Acurácia média: 0.9541919239135176
# Recall médio: 0.3679604045007834
# 107.72360491752625
# 150658
# iniciando treinamento 1
# Acurácia: 0.9695577254451465
# Recall: 1.0
# 4.126108884811401
# iniciando treinamento 2
# Acurácia: 0.9747271682940839
# Recall: 1.0
# 5.050518035888672
# iniciando treinamento 3
# Acurácia: 0.9718552556002298
# Recall: 1.0
# 4.877011299133301
# iniciando treinamento 4
# Acurácia: 0.9712808730614589
# Recall: 1.0
# 4.883986473083496
# iniciando treinamento 5
# Acurácia: 0.983917288914417
# Recall: 1.0
# 3.6440227031707764
# iniciando treinamento 6
# Acurácia: 0.9770246984491672
# Recall: 1.0
# 4.187191724777222
# iniciando treinamento 7
# Acurácia: 0.9827685238368754
# Recall: 1.0
# 4.442516565322876
# iniciando treinamento 8
# Acurácia: 0.9701321079839172
# Recall: 1.0
# 5.245590448379517
# iniciando treinamento 9
# Acurácia: 0.9764503159103963
# Recall: 1.0
# 5.108103513717651
# iniciando treinamento 10
# Acurácia: 0.9735632183908046
# Recall: 1.0
# 5.362183570861816
# Acurácia média: 0.9751277175886497
# Recall médio: 1.0
# 46.989734172821045
# 445485
# iniciando treinamento 1
# Acurácia: 0.9866666666666667
# Recall: 1.0
# 0.15705490112304688
# iniciando treinamento 2
# Acurácia: 1.0
# Recall: 1.0
# 0.14192485809326172
# iniciando treinamento 3
# Acurácia: 0.972972972972973
# Recall: 1.0
# 0.10669302940368652
# iniciando treinamento 4
# Acurácia: 0.8918918918918919
# Recall: 1.0
# 0.13301801681518555
# iniciando treinamento 5
# Acurácia: 0.9594594594594594
# Recall: 1.0
# 0.11847853660583496
# iniciando treinamento 6
# Acurácia: 0.9864864864864865
# Recall: 1.0
# 0.09840631484985352
# iniciando treinamento 7
# Acurácia: 1.0
# Recall: 1.0
# 0.11967611312866211
# iniciando treinamento 8
# Acurácia: 0.972972972972973
# Recall: 1.0
# 0.11384797096252441
# iniciando treinamento 9
# Acurácia: 0.9864864864864865
# Recall: 1.0
# 0.1345829963684082
# iniciando treinamento 10
# Acurácia: 0.972972972972973
# Recall: 1.0
# 0.11586284637451172
# Acurácia média: 0.9729909909909912
# Recall médio: 1.0
# 1.2555785179138184
# 402920
# iniciando treinamento 1
# Acurácia: 0.9772727272727273
# Recall: 0.0
# 0.015317201614379883
# iniciando treinamento 2
# Acurácia: 0.9767441860465116
# Recall: 0.0
# 0.015674591064453125
# iniciando treinamento 3
# Acurácia: 0.9767441860465116
# Recall: 0.0
# 0.018210887908935547
# iniciando treinamento 4
# Acurácia: 0.9767441860465116
# Recall: 0.0
# 0.016779422760009766
# iniciando treinamento 5
# Acurácia: 0.9767441860465116
# Recall: 0.0
# 0.01712489128112793
# iniciando treinamento 6
# Acurácia: 0.9767441860465116
# Recall: 0.0
# 0.016391277313232422
# iniciando treinamento 7
# Acurácia: 0.9767441860465116
# Recall: 0.0
# 0.03335404396057129
# iniciando treinamento 8
# Acurácia: 0.9767441860465116
# Recall: 0.0
# 0.017008066177368164
# iniciando treinamento 9
# Acurácia: 0.9767441860465116
# Recall: 0.0
# 0.03180289268493652
# iniciando treinamento 10
# Acurácia: 0.9767441860465116
# Recall: 0.0
# 0.027005910873413086
# Acurácia média: 0.976797040169133
# Recall médio: 0.0
# 0.22386693954467773
# 150877
# iniciando treinamento 1
# Acurácia: 0.9743589743589743
# Recall: 1.0
# 0.08303189277648926
# iniciando treinamento 2
# Acurácia: 0.9487179487179487
# Recall: 1.0
# 0.0839385986328125
# iniciando treinamento 3
# Acurácia: 0.9230769230769231
# Recall: 1.0
# 0.09100675582885742
# iniciando treinamento 4
# Acurácia: 1.0
# Recall: 1.0
# 0.08940982818603516
# iniciando treinamento 5
# Acurácia: 0.9736842105263158
# Recall: 0.0
# 0.06254434585571289
# iniciando treinamento 6
# Acurácia: 0.9473684210526315
# Recall: 1.0
# 0.09238433837890625
# iniciando treinamento 7
# Acurácia: 0.9736842105263158
# Recall: 1.0
# 0.08064436912536621
# iniciando treinamento 8
# Acurácia: 1.0
# Recall: 1.0
# 0.06586956977844238
# iniciando treinamento 9
# Acurácia: 1.0
# Recall: 1.0
# 0.07758069038391113
# iniciando treinamento 10
# Acurácia: 0.9736842105263158
# Recall: 1.0
# 0.06384968757629395
# Acurácia média: 0.9714574898785425
# Recall médio: 0.9
# 0.7952921390533447
# 481567
# iniciando treinamento 1
# Acurácia: 0.9444444444444444
# Recall: 1.0
# 0.11201214790344238
# iniciando treinamento 2
# Acurácia: 0.8888888888888888
# Recall: 1.0
# 0.14186882972717285
# iniciando treinamento 3
# Acurácia: 0.9722222222222222
# Recall: 0.0
# 0.10340023040771484
# iniciando treinamento 4
# Acurácia: 0.9722222222222222
# Recall: 0.0
# 0.12633228302001953
# iniciando treinamento 5
# Acurácia: 0.9444444444444444
# Recall: 1.0
# 0.12525010108947754
# iniciando treinamento 6
# Acurácia: 1.0
# Recall: 1.0
# 0.11200261116027832
# iniciando treinamento 7
# Acurácia: 0.9722222222222222
# Recall: 1.0
# 0.16626644134521484
# iniciando treinamento 8
# Acurácia: 0.9714285714285714
# Recall: 1.0
# 0.14944934844970703
# iniciando treinamento 9
# Acurácia: 0.9714285714285714
# Recall: 0.0
# 0.12940073013305664
# iniciando treinamento 10
# Acurácia: 1.0
# Recall: 1.0
# 0.12656259536743164
# Acurácia média: 0.9637301587301588
# Recall médio: 0.7
# 1.3151004314422607
# 460872
# iniciando treinamento 1
# Acurácia: 0.9714285714285714
# Recall: 1.0
# 0.07903146743774414
# iniciando treinamento 2
# Acurácia: 0.9428571428571428
# Recall: 0.0
# 0.042059898376464844
# iniciando treinamento 3
# Acurácia: 0.9714285714285714
# Recall: 0.5
# 0.05045461654663086
# iniciando treinamento 4
# Acurácia: 0.9714285714285714
# Recall: 0.5
# 0.05036306381225586
# iniciando treinamento 5
# Acurácia: 0.9714285714285714
# Recall: 1.0
# 0.1180427074432373
# iniciando treinamento 6
# Acurácia: 0.9714285714285714
# Recall: 1.0
# 0.0771944522857666
# iniciando treinamento 7
# Acurácia: 1.0
# Recall: 1.0
# 0.07874321937561035
# iniciando treinamento 8
# Acurácia: 1.0
# Recall: 1.0
# 0.03173494338989258
# iniciando treinamento 9
# Acurácia: 0.9705882352941176
# Recall: 1.0
# 0.04693150520324707
# iniciando treinamento 10
# Acurácia: 0.9705882352941176
# Recall: 0.5
# 0.03168320655822754
# Acurácia média: 0.9741176470588234
# Recall médio: 0.75
# 0.621258020401001
# 469793
# iniciando treinamento 1
# Acurácia: 0.9285714285714286
# Recall: 0.0
# 0.024158716201782227
# iniciando treinamento 2
# Acurácia: 0.9285714285714286
# Recall: 0.0
# 0.007116794586181641
# iniciando treinamento 3
# Acurácia: 0.9285714285714286
# Recall: 0.0
# 0.03967094421386719
# iniciando treinamento 4
# Acurácia: 0.9642857142857143
# Recall: 0.0
# 0.009003400802612305
# iniciando treinamento 5
# Acurácia: 0.9642857142857143
# Recall: 0.0
# 0.020545482635498047
# iniciando treinamento 6
# Acurácia: 0.9642857142857143
# Recall: 0.0
# 0.014967679977416992
# iniciando treinamento 7
# Acurácia: 0.9642857142857143
# Recall: 0.0
# 0.016376972198486328
# iniciando treinamento 8
# Acurácia: 0.9629629629629629
# Recall: 0.0
# 0.016678810119628906
# iniciando treinamento 9
# Acurácia: 0.9629629629629629
# Recall: 0.0
# 0.05078530311584473
# iniciando treinamento 10
# Acurácia: 0.9629629629629629
# Recall: 0.0
# 0.017225980758666992
# Acurácia média: 0.9531746031746033
# Recall médio: 0.0
# 0.23552513122558594
# 461652
# iniciando treinamento 1
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.06723380088806152
# iniciando treinamento 2
# Acurácia: 0.9047619047619048
# Recall: 0.0
# 0.049898386001586914
# iniciando treinamento 3
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.032530784606933594
# iniciando treinamento 4
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.06148123741149902
# iniciando treinamento 5
# Acurácia: 0.9523809523809523
# Recall: 1.0
# 0.031249523162841797
# iniciando treinamento 6
# Acurácia: 0.9523809523809523
# Recall: 1.0
# 0.04757976531982422
# iniciando treinamento 7
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.0469355583190918
# iniciando treinamento 8
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.047376155853271484
# iniciando treinamento 9
# Acurácia: 1.0
# Recall: 1.0
# 0.0491487979888916
# iniciando treinamento 10
# Acurácia: 1.0
# Recall: 0.0
# 0.050506591796875
# Acurácia média: 0.9571428571428573
# Recall médio: 0.3
# 0.48394060134887695
# 464381
# iniciando treinamento 1
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.06384396553039551
# iniciando treinamento 2
# Acurácia: 0.9047619047619048
# Recall: 0.0
# 0.05175423622131348
# iniciando treinamento 3
# Acurácia: 0.9047619047619048
# Recall: 0.0
# 0.06386446952819824
# iniciando treinamento 4
# Acurácia: 0.8571428571428571
# Recall: 0.0
# 0.06845283508300781
# iniciando treinamento 5
# Acurácia: 0.8571428571428571
# Recall: 0.0
# 0.05785655975341797
# iniciando treinamento 6
# Acurácia: 0.95
# Recall: 0.0
# 0.06291675567626953
# iniciando treinamento 7
# Acurácia: 0.95
# Recall: 0.0
# 0.04710197448730469
# iniciando treinamento 8
# Acurácia: 0.9
# Recall: 0.0
# 0.04912853240966797
# iniciando treinamento 9
# Acurácia: 1.0
# Recall: 0.0
# 0.06910109519958496
# iniciando treinamento 10
# Acurácia: 0.95
# Recall: 0.0
# 0.05640864372253418
# Acurácia média: 0.9226190476190477
# Recall médio: 0.0
# 0.6073238849639893

# %% [markdown]
# # Imprime a tabela final de avaliação

# %%
tabelafinal.sort_values("recall", axis = 0, ascending = False,
                 inplace = True, na_position ='last')
print(tabelafinal)
# Out:
#    material  acuracia   recall       tempo
# 1  150658.0  0.975128  1.00000   46.989734
# 2  445485.0  0.972991  1.00000    1.255579
# 4  150877.0  0.971457  0.90000    0.795292
# 6  460872.0  0.974118  0.75000    0.621258
# 5  481567.0  0.963730  0.70000    1.315100
# 0  104671.0  0.954192  0.36796  107.723605
# 8  461652.0  0.957143  0.30000    0.483941
# 3  402920.0  0.976797  0.00000    0.223867
# 7  469793.0  0.953175  0.00000    0.235525
# 9  464381.0  0.922619  0.00000    0.607324
