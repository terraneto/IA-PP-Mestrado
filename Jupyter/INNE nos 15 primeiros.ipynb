# %% [markdown]
# # INNE nos 15 primeiros
# Teste do SUOD  para comparação e seleção dos integrantes do aplicativo

# %%
import numpy as np
import pandas as pd
import os
from sklearn.metrics import accuracy_score,recall_score
from pyod.utils.data import evaluate_print
import time

# Importa bibliotecas do PyOD com os algoritmos de detecção de anomalias
from pyod.models.inne import INNE
from pyod.models.abod import ABOD
from pyod.models.cblof import CBLOF
from pyod.models.knn import KNN
from pyod.models.lof import LOF
from pyod.models.pca import PCA
from pyod.models.sampling import Sampling
from pyod.models.ecod import ECOD
from pyod.models.copod import COPOD
from pyod.models.suod import SUOD
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score

tabelafinal = pd.DataFrame(columns=['material','acuracia','recall','tempo'])
print(tabelafinal)
      
def carrega_material(path,material):
    arquivo = str(material)+".csv"
    csv_path = os.path.join(path,arquivo)
    df = pd.read_csv(csv_path)
    ## Retira os campos que não serão utilizados no treinamento
    df = df.drop(['licitacao_contrato'],axis=1)
    df = df.drop(['id'],axis=1)
    df = df.drop(['data'],axis=1)
    df = df.drop(['catmat_id'],axis=1)
    df = df.drop(['unidade'],axis=1)
    df = df.drop(['valor_total'],axis=1)
    df = df.drop(['municipio_uasg'],axis=1)
    df = df.drop(['municipio_fornecedor'],axis=1)
    return df
# Out:
# Empty DataFrame
# Columns: [material, acuracia, recall, tempo]
# Index: []

# %%
from sqlalchemy import create_engine
import pymysql
from sqlalchemy.dialects.mysql import insert
import pandas as pd
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
itens = pd.read_sql("SELECT * from siasg.itens", dbConnection);

maioresitens = pd.read_sql("SELECT catmat_id, count(*) from siasg.itens where valor_unitario>0 and catmat_id!=0 group by catmat_id order by count(*) desc", dbConnection);

# %% [markdown]
# # Recuperação dos dados a serem utilizados na avaliação

# %%
##Carrega os dados do item
for index, row in maioresitens.iterrows():
    iniciomaterial = time.time()
    catmat = row['catmat_id']
    df=carrega_material(".",catmat)  
    print(catmat)
    # Separação do Label dos dados
    x = df.iloc[:, :-1]
    y = df.iloc[:, -1]
    #if index<2:
    #    continue
    detector_list = [
             INNE(contamination=0.05, n_estimators=50, random_state= 69), 
             ABOD(contamination=0.05, method= 'default', n_neighbors=20),
             CBLOF(contamination=0.05, n_clusters=2),
             KNN(contamination=0.05, leaf_size=10, method='largest', n_neighbors=10),
             LOF(contamination=0.05, leaf_size=1, n_neighbors=34),  
             PCA(contamination=0.05, n_components=3, n_selected_components=1),
             Sampling(contamination=0.05, subset_size=10),
             ECOD(contamination=0.09),
             COPOD(contamination=0.12)
    ]

    # Inicializar o modelo SUOD
    model = INNE(contamination=0.05, n_estimators=50, random_state= 69)

    # Definir a validação cruzada estratificada
    cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=69)

    acuracia=[]
    recall=[]

    # Loop para treinar e testar o modelo
    k=1
    for train_index, test_index in cv.split(x,y):
        iniciofold = time.time()
        print('iniciando treinamento '+str(k))
        X_train, X_test = x.iloc[train_index], x.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Treinar o modelo
        model.fit(X_train)

        # Fazer as previsões
        y_pred = model.predict(X_test)

        # Calcular a acurácia
        acc = accuracy_score(y_test, y_pred)
        print(f'Acurácia: {acc}')
        acuracia.append(acc)

        # Calcular o Recall
        rec = recall_score(y_test, y_pred)
        print(f'Recall: {rec}')
        recall.append(rec)
        fimfold = time.time()
        tempofold = fimfold-iniciofold
        print(tempofold)
        k+=1

    acuracia_media = sum(acuracia) / len(acuracia)
    recall_medio = sum(recall) / len(recall)


    print(f'Acurácia média: {acuracia_media}')
    print(f'Recall médio: {recall_medio}')
    fim = time.time()
    tempo = fim-iniciomaterial
    print(tempo)
    
    # Grava os resultados da avaliação na tabela final
    tabelafinal.loc[len(tabelafinal.index)] = [catmat,acuracia_media,recall_medio,tempo] 
    if index==9:
        break
# Out:
# 104671
# iniciando treinamento 1
# Acurácia: 0.9635021097046413
# Recall: 0.6722689075630253
# 0.4915299415588379
# iniciando treinamento 2
# Acurácia: 0.979957805907173
# Recall: 0.3445378151260504
# 0.47983622550964355
# iniciando treinamento 3
# Acurácia: 0.9641350210970464
# Recall: 0.8907563025210085
# 0.4648854732513428
# iniciando treinamento 4
# Acurácia: 0.9727848101265822
# Recall: 0.9747899159663865
# 0.5213994979858398
# iniciando treinamento 5
# Acurácia: 0.954420763874235
# Recall: 0.4322033898305085
# 0.534520149230957
# iniciando treinamento 6
# Acurácia: 0.9881831610044313
# Recall: 0.6271186440677966
# 1.3827261924743652
# iniciando treinamento 7
# Acurácia: 0.9767883519729901
# Recall: 0.9915254237288136
# 1.257746934890747
# iniciando treinamento 8
# Acurácia: 0.9820637265245833
# Recall: 0.4576271186440678
# 1.3005619049072266
# iniciando treinamento 9
# Acurácia: 0.9755222620806078
# Recall: 0.940677966101695
# 1.3422601222991943
# iniciando treinamento 10
# Acurácia: 0.9767883519729901
# Recall: 0.2857142857142857
# 1.1970281600952148
# Acurácia média: 0.973414636426528
# Recall médio: 0.6617219769263637
# 9.043417930603027
# 150658
# iniciando treinamento 1
# Acurácia: 0.9638139000574383
# Recall: 0.9069767441860465
# 0.4619605541229248
# iniciando treinamento 2
# Acurácia: 0.9781734635267088
# Recall: 1.0
# 0.6034884452819824
# iniciando treinamento 3
# Acurácia: 0.9592188397472717
# Recall: 0.5813953488372093
# 0.6412868499755859
# iniciando treinamento 4
# Acurácia: 0.9483055715106261
# Recall: 0.2727272727272727
# 0.46918773651123047
# iniciando treinamento 5
# Acurácia: 0.9529006318207927
# Recall: 0.4318181818181818
# 0.43286776542663574
# iniciando treinamento 6
# Acurácia: 0.9798966111430213
# Recall: 1.0
# 0.42311835289001465
# iniciando treinamento 7
# Acurácia: 0.941987363584147
# Recall: 0.25
# 0.5228195190429688
# iniciando treinamento 8
# Acurácia: 0.9350947731188972
# Recall: 0.045454545454545456
# 0.6361639499664307
# iniciando treinamento 9
# Acurácia: 0.9391154508902929
# Recall: 0.29545454545454547
# 0.4533085823059082
# iniciando treinamento 10
# Acurácia: 0.9408045977011494
# Recall: 0.23255813953488372
# 0.46939826011657715
# Acurácia média: 0.9539311203100345
# Recall médio: 0.5016384778012686
# 5.168587684631348
# 445485
# iniciando treinamento 1
# Acurácia: 0.9866666666666667
# Recall: 1.0
# 0.0862424373626709
# iniciando treinamento 2
# Acurácia: 1.0
# Recall: 1.0
# 0.0968782901763916
# iniciando treinamento 3
# Acurácia: 0.9864864864864865
# Recall: 1.0
# 0.1113286018371582
# iniciando treinamento 4
# Acurácia: 0.8918918918918919
# Recall: 0.5
# 0.11824655532836914
# iniciando treinamento 5
# Acurácia: 0.9594594594594594
# Recall: 1.0
# 0.09422540664672852
# iniciando treinamento 6
# Acurácia: 0.9594594594594594
# Recall: 1.0
# 0.07856225967407227
# iniciando treinamento 7
# Acurácia: 0.9864864864864865
# Recall: 1.0
# 0.09414124488830566
# iniciando treinamento 8
# Acurácia: 0.972972972972973
# Recall: 1.0
# 0.1099395751953125
# iniciando treinamento 9
# Acurácia: 0.9864864864864865
# Recall: 1.0
# 0.11024117469787598
# iniciando treinamento 10
# Acurácia: 1.0
# Recall: 1.0
# 0.09444475173950195
# Acurácia média: 0.9729909909909911
# Recall médio: 0.95
# 1.0112526416778564
# 402920
# iniciando treinamento 1
# Acurácia: 1.0
# Recall: 1.0
# 0.11112046241760254
# iniciando treinamento 2
# Acurácia: 1.0
# Recall: 1.0
# 0.07578563690185547
# iniciando treinamento 3
# Acurácia: 1.0
# Recall: 1.0
# 0.09462594985961914
# iniciando treinamento 4
# Acurácia: 0.9767441860465116
# Recall: 1.0
# 0.09111332893371582
# iniciando treinamento 5
# Acurácia: 1.0
# Recall: 1.0
# 0.09413766860961914
# iniciando treinamento 6
# Acurácia: 1.0
# Recall: 1.0
# 0.09401988983154297
# iniciando treinamento 7
# Acurácia: 1.0
# Recall: 1.0
# 0.09423589706420898
# iniciando treinamento 8
# Acurácia: 1.0
# Recall: 1.0
# 0.07882261276245117
# iniciando treinamento 9
# Acurácia: 1.0
# Recall: 1.0
# 0.09425902366638184
# iniciando treinamento 10
# Acurácia: 1.0
# Recall: 1.0
# 0.09540557861328125
# Acurácia média: 0.9976744186046511
# Recall médio: 1.0
# 0.9391496181488037
# 150877
# iniciando treinamento 1
# Acurácia: 0.9743589743589743
# Recall: 1.0
# 0.07852721214294434
# iniciando treinamento 2
# Acurácia: 0.9487179487179487
# Recall: 1.0
# 0.09854412078857422
# iniciando treinamento 3
# Acurácia: 0.9230769230769231
# Recall: 1.0
# 0.10005331039428711
# iniciando treinamento 4
# Acurácia: 1.0
# Recall: 1.0
# 0.10687923431396484
# iniciando treinamento 5
# Acurácia: 0.9736842105263158
# Recall: 0.0
# 0.07823753356933594
# iniciando treinamento 6
# Acurácia: 0.9473684210526315
# Recall: 1.0
# 0.09364032745361328
# iniciando treinamento 7
# Acurácia: 0.9736842105263158
# Recall: 1.0
# 0.09415054321289062
# iniciando treinamento 8
# Acurácia: 1.0
# Recall: 1.0
# 0.10071396827697754
# iniciando treinamento 9
# Acurácia: 1.0
# Recall: 1.0
# 0.0840151309967041
# iniciando treinamento 10
# Acurácia: 0.9736842105263158
# Recall: 1.0
# 0.04969501495361328
# Acurácia média: 0.9714574898785425
# Recall médio: 0.9
# 0.8997392654418945
# 481567
# iniciando treinamento 1
# Acurácia: 0.9722222222222222
# Recall: 1.0
# 0.049257516860961914
# iniciando treinamento 2
# Acurácia: 0.9166666666666666
# Recall: 0.0
# 0.06859946250915527
# iniciando treinamento 3
# Acurácia: 0.9722222222222222
# Recall: 1.0
# 0.048842668533325195
# iniciando treinamento 4
# Acurácia: 1.0
# Recall: 1.0
# 0.06521940231323242
# iniciando treinamento 5
# Acurácia: 0.9444444444444444
# Recall: 1.0
# 0.05484485626220703
# iniciando treinamento 6
# Acurácia: 0.9444444444444444
# Recall: 0.0
# 0.046524763107299805
# iniciando treinamento 7
# Acurácia: 0.9722222222222222
# Recall: 1.0
# 0.06676626205444336
# iniciando treinamento 8
# Acurácia: 0.9142857142857143
# Recall: 0.0
# 0.07851886749267578
# iniciando treinamento 9
# Acurácia: 0.9428571428571428
# Recall: 0.0
# 0.10460662841796875
# iniciando treinamento 10
# Acurácia: 0.9714285714285714
# Recall: 1.0
# 0.09502458572387695
# Acurácia média: 0.9550793650793651
# Recall médio: 0.6
# 0.6950719356536865
# 460872
# iniciando treinamento 1
# Acurácia: 1.0
# Recall: 1.0
# 0.08533835411071777
# iniciando treinamento 2
# Acurácia: 0.9142857142857143
# Recall: 0.0
# 0.08793091773986816
# iniciando treinamento 3
# Acurácia: 0.9714285714285714
# Recall: 0.5
# 0.09401917457580566
# iniciando treinamento 4
# Acurácia: 0.9714285714285714
# Recall: 0.5
# 0.08062386512756348
# iniciando treinamento 5
# Acurácia: 0.9714285714285714
# Recall: 1.0
# 0.08077168464660645
# iniciando treinamento 6
# Acurácia: 0.9428571428571428
# Recall: 1.0
# 0.1024932861328125
# iniciando treinamento 7
# Acurácia: 1.0
# Recall: 1.0
# 0.08296751976013184
# iniciando treinamento 8
# Acurácia: 0.9705882352941176
# Recall: 1.0
# 0.0943448543548584
# iniciando treinamento 9
# Acurácia: 1.0
# Recall: 1.0
# 0.07822728157043457
# iniciando treinamento 10
# Acurácia: 0.9411764705882353
# Recall: 0.5
# 0.08278727531433105
# Acurácia média: 0.9683193277310924
# Recall médio: 0.75
# 0.8846144676208496
# 469793
# iniciando treinamento 1
# Acurácia: 1.0
# Recall: 1.0
# 0.07772707939147949
# iniciando treinamento 2
# Acurácia: 1.0
# Recall: 1.0
# 0.08237028121948242
# iniciando treinamento 3
# Acurácia: 1.0
# Recall: 1.0
# 0.08489632606506348
# iniciando treinamento 4
# Acurácia: 1.0
# Recall: 1.0
# 0.06619429588317871
# iniciando treinamento 5
# Acurácia: 1.0
# Recall: 1.0
# 0.10054826736450195
# iniciando treinamento 6
# Acurácia: 1.0
# Recall: 1.0
# 0.0933694839477539
# iniciando treinamento 7
# Acurácia: 1.0
# Recall: 1.0
# 0.07271456718444824
# iniciando treinamento 8
# Acurácia: 1.0
# Recall: 1.0
# 0.08439326286315918
# iniciando treinamento 9
# Acurácia: 1.0
# Recall: 1.0
# 0.08907175064086914
# iniciando treinamento 10
# Acurácia: 1.0
# Recall: 1.0
# 0.07915496826171875
# Acurácia média: 1.0
# Recall médio: 1.0
# 0.8480212688446045
# 461652
# iniciando treinamento 1
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.08727550506591797
# iniciando treinamento 2
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.08500051498413086
# iniciando treinamento 3
# Acurácia: 0.9047619047619048
# Recall: 0.0
# 0.06660032272338867
# iniciando treinamento 4
# Acurácia: 0.9047619047619048
# Recall: 0.0
# 0.08335208892822266
# iniciando treinamento 5
# Acurácia: 0.9523809523809523
# Recall: 1.0
# 0.08770275115966797
# iniciando treinamento 6
# Acurácia: 0.9047619047619048
# Recall: 0.0
# 0.0640723705291748
# iniciando treinamento 7
# Acurácia: 0.8571428571428571
# Recall: 1.0
# 0.08463501930236816
# iniciando treinamento 8
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.08152484893798828
# iniciando treinamento 9
# Acurácia: 0.8095238095238095
# Recall: 1.0
# 0.08396267890930176
# iniciando treinamento 10
# Acurácia: 1.0
# Recall: 0.0
# 0.06413888931274414
# Acurácia média: 0.919047619047619
# Recall médio: 0.3
# 0.7882649898529053
# 464381
# iniciando treinamento 1
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.07863140106201172
# iniciando treinamento 2
# Acurácia: 0.8571428571428571
# Recall: 0.0
# 0.09014296531677246
# iniciando treinamento 3
# Acurácia: 0.8095238095238095
# Recall: 0.0
# 0.08216238021850586
# iniciando treinamento 4
# Acurácia: 0.8571428571428571
# Recall: 0.0
# 0.07867884635925293
# iniciando treinamento 5
# Acurácia: 0.8571428571428571
# Recall: 0.0
# 0.07847905158996582
# iniciando treinamento 6
# Acurácia: 0.95
# Recall: 0.0
# 0.08620810508728027
# iniciando treinamento 7
# Acurácia: 0.9
# Recall: 0.0
# 0.07425451278686523
# iniciando treinamento 8
# Acurácia: 0.9
# Recall: 0.0
# 0.06840729713439941
# iniciando treinamento 9
# Acurácia: 1.0
# Recall: 0.0
# 0.0930473804473877
# iniciando treinamento 10
# Acurácia: 0.95
# Recall: 0.0
# 0.08723306655883789
# Acurácia média: 0.9033333333333333
# Recall médio: 0.0
# 0.8172450065612793

# %% [markdown]
# # Imprime a tabela final de avaliação

# %%
tabelafinal.sort_values("recall", axis = 0, ascending = False,
                 inplace = True, na_position ='last')
print(tabelafinal)
# Out:
#    material  acuracia    recall     tempo
# 3  402920.0  0.997674  1.000000  0.939150
# 7  469793.0  1.000000  1.000000  0.848021
# 2  445485.0  0.972991  0.950000  1.011253
# 4  150877.0  0.971457  0.900000  0.899739
# 6  460872.0  0.968319  0.750000  0.884614
# 0  104671.0  0.973415  0.661722  9.043418
# 5  481567.0  0.955079  0.600000  0.695072
# 1  150658.0  0.953931  0.501638  5.168588
# 8  461652.0  0.919048  0.300000  0.788265
# 9  464381.0  0.903333  0.000000  0.817245
