# %% [markdown]
# # Sampling nos 10 primeiros
# Teste do SUOD  para comparação e seleção dos integrantes do aplicativo

# %%
import numpy as np
import pandas as pd
import os
from sklearn.metrics import accuracy_score,recall_score
from pyod.utils.data import evaluate_print
import time

# Importa bibliotecas do PyOD com os algoritmos de detecção de anomalias
from pyod.models.inne import INNE
from pyod.models.abod import ABOD
from pyod.models.cblof import CBLOF
from pyod.models.knn import KNN
from pyod.models.lof import LOF
from pyod.models.pca import PCA
from pyod.models.sampling import Sampling
from pyod.models.ecod import ECOD
from pyod.models.copod import COPOD
from pyod.models.suod import SUOD
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score

tabelafinal = pd.DataFrame(columns=['material','acuracia','recall','tempo'])
print(tabelafinal)
      
def carrega_material(path,material):
    arquivo = str(material)+".csv"
    csv_path = os.path.join(path,arquivo)
    df = pd.read_csv(csv_path)
    ## Retira os campos que não serão utilizados no treinamento
    df = df.drop(['licitacao_contrato'],axis=1)
    df = df.drop(['id'],axis=1)
    df = df.drop(['data'],axis=1)
    df = df.drop(['catmat_id'],axis=1)
    df = df.drop(['unidade'],axis=1)
    df = df.drop(['valor_total'],axis=1)
    df = df.drop(['municipio_uasg'],axis=1)
    df = df.drop(['municipio_fornecedor'],axis=1)
    return df
# Out:
# Empty DataFrame
# Columns: [material, acuracia, recall, tempo]
# Index: []

# %%
from sqlalchemy import create_engine
import pymysql
from sqlalchemy.dialects.mysql import insert
import pandas as pd
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
itens = pd.read_sql("SELECT * from siasg.itens", dbConnection);

maioresitens = pd.read_sql("SELECT catmat_id, count(*) from siasg.itens where valor_unitario>0 and catmat_id!=0 group by catmat_id order by count(*) desc", dbConnection);

# %% [markdown]
# # Recuperação dos dados a serem utilizados na avaliação

# %%
##Carrega os dados do item
for index, row in maioresitens.iterrows():
    iniciomaterial = time.time()
    catmat = row['catmat_id']
    df=carrega_material(".",catmat)  
    print(catmat)
    # Separação do Label dos dados
    x = df.iloc[:, :-1]
    y = df.iloc[:, -1]
    #if index<2:
    #    continue
    detector_list = [
             INNE(contamination=0.05, n_estimators=50, random_state= 69), 
             ABOD(contamination=0.05, method= 'default', n_neighbors=20),
             CBLOF(contamination=0.05, n_clusters=2),
             KNN(contamination=0.05, leaf_size=10, method='largest', n_neighbors=10),
             LOF(contamination=0.05, leaf_size=1, n_neighbors=34),  
             PCA(contamination=0.05, n_components=3, n_selected_components=1),
             Sampling(contamination=0.05, subset_size=10),
             ECOD(contamination=0.09),
             COPOD(contamination=0.12)
    ]

    # Inicializar o modelo SUOD
    model = Sampling(contamination=0.05, subset_size=10)

    # Definir a validação cruzada estratificada
    cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=69)

    acuracia=[]
    recall=[]

    # Loop para treinar e testar o modelo
    k=1
    for train_index, test_index in cv.split(x,y):
        iniciofold = time.time()
        print('iniciando treinamento '+str(k))
        X_train, X_test = x.iloc[train_index], x.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Treinar o modelo
        model.fit(X_train)

        # Fazer as previsões
        y_pred = model.predict(X_test)

        # Calcular a acurácia
        acc = accuracy_score(y_test, y_pred)
        print(f'Acurácia: {acc}')
        acuracia.append(acc)

        # Calcular o Recall
        rec = recall_score(y_test, y_pred)
        print(f'Recall: {rec}')
        recall.append(rec)
        fimfold = time.time()
        tempofold = fimfold-iniciofold
        print(tempofold)
        k+=1

    acuracia_media = sum(acuracia) / len(acuracia)
    recall_medio = sum(recall) / len(recall)


    print(f'Acurácia média: {acuracia_media}')
    print(f'Recall médio: {recall_medio}')
    fim = time.time()
    tempo = fim-iniciomaterial
    print(tempo)
    
    # Grava os resultados da avaliação na tabela final
    tabelafinal.loc[len(tabelafinal.index)] = [catmat,acuracia_media,recall_medio,tempo] 
    if index==9:
        break
# Out:
# 104671
# iniciando treinamento 1
# Acurácia: 0.9377637130801688
# Recall: 0.21008403361344538
# 0.01056671142578125
# iniciando treinamento 2
# Acurácia: 0.9462025316455697
# Recall: 0.3697478991596639
# 0.008999824523925781
# iniciando treinamento 3
# Acurácia: 0.9375527426160337
# Recall: 0.40336134453781514
# 0.004983186721801758
# iniciando treinamento 4
# Acurácia: 0.9791139240506329
# Recall: 1.0
# 0.0
# iniciando treinamento 5
# Acurácia: 0.9438700147710487
# Recall: 0.3474576271186441
# 0.015677213668823242
# iniciando treinamento 6
# Acurácia: 0.9656045579236125
# Recall: 0.788135593220339
# 0.01560521125793457
# iniciando treinamento 7
# Acurácia: 0.9385946402194556
# Recall: 0.2627118644067797
# 0.0019197463989257812
# iniciando treinamento 8
# Acurácia: 0.9725680523317155
# Recall: 1.0
# 0.01401066780090332
# iniciando treinamento 9
# Acurácia: 0.9470352395020046
# Recall: 0.3983050847457627
# 0.0
# iniciando treinamento 10
# Acurácia: 0.9426039248786664
# Recall: 0.35294117647058826
# 0.01616382598876953
# Acurácia média: 0.9510909341018909
# Recall médio: 0.5132744623273038
# 0.138153076171875
# 150658
# iniciando treinamento 1
# Acurácia: 0.9764503159103963
# Recall: 1.0
# 0.015631914138793945
# iniciando treinamento 2
# Acurácia: 0.9747271682940839
# Recall: 1.0
# 0.0
# iniciando treinamento 3
# Acurácia: 0.9724296381390006
# Recall: 1.0
# 0.0
# iniciando treinamento 4
# Acurácia: 0.9730040206777714
# Recall: 1.0
# 0.015799760818481445
# iniciando treinamento 5
# Acurácia: 0.983917288914417
# Recall: 1.0
# 0.0
# iniciando treinamento 6
# Acurácia: 0.9730040206777714
# Recall: 1.0
# 0.0
# iniciando treinamento 7
# Acurácia: 0.9816197587593337
# Recall: 1.0
# 0.015627384185791016
# iniciando treinamento 8
# Acurácia: 0.9695577254451465
# Recall: 1.0
# 0.0061757564544677734
# iniciando treinamento 9
# Acurácia: 0.9764503159103963
# Recall: 1.0
# 0.005003452301025391
# iniciando treinamento 10
# Acurácia: 0.9735632183908046
# Recall: 1.0
# 0.006017208099365234
# Acurácia média: 0.9754723471119121
# Recall médio: 1.0
# 0.08048582077026367
# 445485
# iniciando treinamento 1
# Acurácia: 0.96
# Recall: 0.6666666666666666
# 0.002039194107055664
# iniciando treinamento 2
# Acurácia: 1.0
# Recall: 1.0
# 0.002997159957885742
# iniciando treinamento 3
# Acurácia: 0.9594594594594594
# Recall: 1.0
# 0.0019998550415039062
# iniciando treinamento 4
# Acurácia: 0.9459459459459459
# Recall: 1.0
# 0.003029346466064453
# iniciando treinamento 5
# Acurácia: 0.9594594594594594
# Recall: 1.0
# 0.002000570297241211
# iniciando treinamento 6
# Acurácia: 0.9864864864864865
# Recall: 1.0
# 0.0029985904693603516
# iniciando treinamento 7
# Acurácia: 1.0
# Recall: 1.0
# 0.002007722854614258
# iniciando treinamento 8
# Acurácia: 0.972972972972973
# Recall: 1.0
# 0.0
# iniciando treinamento 9
# Acurácia: 0.9864864864864865
# Recall: 1.0
# 0.0
# iniciando treinamento 10
# Acurácia: 0.972972972972973
# Recall: 1.0
# 0.007554054260253906
# Acurácia média: 0.9743783783783785
# Recall médio: 0.9666666666666666
# 0.030401945114135742
# 402920
# iniciando treinamento 1
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 2
# Acurácia: 1.0
# Recall: 1.0
# 0.00851130485534668
# iniciando treinamento 3
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 4
# Acurácia: 0.9767441860465116
# Recall: 1.0
# 0.0
# iniciando treinamento 5
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 6
# Acurácia: 1.0
# Recall: 1.0
# 0.012478828430175781
# iniciando treinamento 7
# Acurácia: 1.0
# Recall: 1.0
# 0.002161741256713867
# iniciando treinamento 8
# Acurácia: 1.0
# Recall: 1.0
# 0.0027179718017578125
# iniciando treinamento 9
# Acurácia: 1.0
# Recall: 1.0
# 0.002999544143676758
# iniciando treinamento 10
# Acurácia: 1.0
# Recall: 1.0
# 0.002959012985229492
# Acurácia média: 0.9976744186046511
# Recall médio: 1.0
# 0.03182840347290039
# 150877
# iniciando treinamento 1
# Acurácia: 0.9743589743589743
# Recall: 1.0
# 0.0
# iniciando treinamento 2
# Acurácia: 0.9487179487179487
# Recall: 1.0
# 0.010363340377807617
# iniciando treinamento 3
# Acurácia: 0.9487179487179487
# Recall: 1.0
# 0.0026581287384033203
# iniciando treinamento 4
# Acurácia: 1.0
# Recall: 1.0
# 0.0019941329956054688
# iniciando treinamento 5
# Acurácia: 0.9473684210526315
# Recall: 0.0
# 0.0030074119567871094
# iniciando treinamento 6
# Acurácia: 0.9473684210526315
# Recall: 1.0
# 0.0020046234130859375
# iniciando treinamento 7
# Acurácia: 0.9736842105263158
# Recall: 1.0
# 0.0019996166229248047
# iniciando treinamento 8
# Acurácia: 0.9210526315789473
# Recall: 1.0
# 0.0029926300048828125
# iniciando treinamento 9
# Acurácia: 0.9736842105263158
# Recall: 0.0
# 0.0019354820251464844
# iniciando treinamento 10
# Acurácia: 0.9736842105263158
# Recall: 1.0
# 0.003140687942504883
# Acurácia média: 0.9608636977058028
# Recall médio: 0.8
# 0.030096054077148438
# 481567
# iniciando treinamento 1
# Acurácia: 0.9166666666666666
# Recall: 1.0
# 0.001994609832763672
# iniciando treinamento 2
# Acurácia: 0.8888888888888888
# Recall: 1.0
# 0.0030007362365722656
# iniciando treinamento 3
# Acurácia: 0.9722222222222222
# Recall: 1.0
# 0.0019860267639160156
# iniciando treinamento 4
# Acurácia: 0.9722222222222222
# Recall: 1.0
# 0.002903461456298828
# iniciando treinamento 5
# Acurácia: 0.9722222222222222
# Recall: 1.0
# 0.0001308917999267578
# iniciando treinamento 6
# Acurácia: 0.9722222222222222
# Recall: 0.0
# 0.0
# iniciando treinamento 7
# Acurácia: 0.9444444444444444
# Recall: 0.5
# 0.0
# iniciando treinamento 8
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 9
# Acurácia: 0.9428571428571428
# Recall: 0.0
# 0.0
# iniciando treinamento 10
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# Acurácia média: 0.9581746031746032
# Recall médio: 0.75
# 0.014021158218383789
# 460872
# iniciando treinamento 1
# Acurácia: 0.9428571428571428
# Recall: 0.5
# 0.0
# iniciando treinamento 2
# Acurácia: 0.9428571428571428
# Recall: 0.0
# 0.0
# iniciando treinamento 3
# Acurácia: 0.9714285714285714
# Recall: 0.5
# 0.008507013320922852
# iniciando treinamento 4
# Acurácia: 0.9714285714285714
# Recall: 0.5
# 0.0
# iniciando treinamento 5
# Acurácia: 0.9714285714285714
# Recall: 1.0
# 0.0
# iniciando treinamento 6
# Acurácia: 0.9714285714285714
# Recall: 1.0
# 0.0075075626373291016
# iniciando treinamento 7
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 8
# Acurácia: 0.9705882352941176
# Recall: 1.0
# 0.0
# iniciando treinamento 9
# Acurácia: 0.9705882352941176
# Recall: 1.0
# 0.0
# iniciando treinamento 10
# Acurácia: 0.9705882352941176
# Recall: 0.5
# 0.0
# Acurácia média: 0.9683193277310924
# Recall médio: 0.7
# 0.03167295455932617
# 469793
# iniciando treinamento 1
# Acurácia: 1.0
# Recall: 1.0
# 0.015633106231689453
# iniciando treinamento 2
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 3
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 4
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 5
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 6
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 7
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 8
# Acurácia: 1.0
# Recall: 1.0
# 0.015625715255737305
# iniciando treinamento 9
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 10
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# Acurácia média: 1.0
# Recall médio: 1.0
# 0.03125882148742676
# 461652
# iniciando treinamento 1
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.0
# iniciando treinamento 2
# Acurácia: 0.9047619047619048
# Recall: 0.0
# 0.0
# iniciando treinamento 3
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.01563239097595215
# iniciando treinamento 4
# Acurácia: 1.0
# Recall: 0.0
# 0.0
# iniciando treinamento 5
# Acurácia: 0.9523809523809523
# Recall: 1.0
# 0.0
# iniciando treinamento 6
# Acurácia: 0.9523809523809523
# Recall: 1.0
# 0.0
# iniciando treinamento 7
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.0
# iniciando treinamento 8
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.0
# iniciando treinamento 9
# Acurácia: 0.9523809523809523
# Recall: 1.0
# 0.01572251319885254
# iniciando treinamento 10
# Acurácia: 1.0
# Recall: 0.0
# 0.0
# Acurácia média: 0.9571428571428571
# Recall médio: 0.3
# 0.03135490417480469
# 464381
# iniciando treinamento 1
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.0
# iniciando treinamento 2
# Acurácia: 0.8571428571428571
# Recall: 0.0
# 0.0
# iniciando treinamento 3
# Acurácia: 0.9047619047619048
# Recall: 0.0
# 0.0
# iniciando treinamento 4
# Acurácia: 0.8571428571428571
# Recall: 0.0
# 0.01552438735961914
# iniciando treinamento 5
# Acurácia: 0.8571428571428571
# Recall: 0.0
# 0.0
# iniciando treinamento 6
# Acurácia: 0.95
# Recall: 0.0
# 0.0
# iniciando treinamento 7
# Acurácia: 0.95
# Recall: 0.0
# 0.0
# iniciando treinamento 8
# Acurácia: 0.9
# Recall: 0.0
# 0.0
# iniciando treinamento 9
# Acurácia: 1.0
# Recall: 0.0
# 0.014610052108764648
# iniciando treinamento 10
# Acurácia: 0.95
# Recall: 0.0
# 0.0016124248504638672
# Acurácia média: 0.9178571428571427
# Recall médio: 0.0
# 0.031746864318847656

# %% [markdown]
# # Imprime a tabela final de avaliação

# %%
tabelafinal.sort_values("recall", axis = 0, ascending = False,
                 inplace = True, na_position ='last')
print(tabelafinal)
# Out:
#    material  acuracia    recall     tempo
# 1  150658.0  0.975472  1.000000  0.080486
# 3  402920.0  0.997674  1.000000  0.031828
# 7  469793.0  1.000000  1.000000  0.031259
# 2  445485.0  0.974378  0.966667  0.030402
# 4  150877.0  0.960864  0.800000  0.030096
# 5  481567.0  0.958175  0.750000  0.014021
# 6  460872.0  0.968319  0.700000  0.031673
# 0  104671.0  0.951091  0.513274  0.138153
# 8  461652.0  0.957143  0.300000  0.031355
# 9  464381.0  0.917857  0.000000  0.031747
