# %% [markdown]
# # Recupera e carrega os dados do módulo de fornecedores na base Mysql

# %% [markdown]
# # Fornecedores

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
vtabela = 'fornecedores'
vtabelasiasg= 'fornecedores'
vlink = 'http://compras.dados.gov.br/fornecedores/v1/fornecedores.json?offset='
url = 'http://compras.dados.gov.br/fornecedores/v1/fornecedores.json'
chavetabela = 'alter table "'
chavetabela = chavetabela +vtabela
chavetabela = chavetabela +'"'
chavetabela = chavetabela  + ' add primary key (id)'
createindex= False

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt) 
    
responserdc = urlopen(url)
data_json = json.loads(responserdc.read())
numfornec=data_json["count"]
# Mostra número de registros e número de páginas
print(numfornec)
numpagsfornec = numfornec // 500
print(numpagsfornec)   
pag = 0
numpag = numpagsfornec
num=0
while pag<=numpag:
    valpag=500*pag
    url = vlink+str(valpag)
    try:
        response = urlopen(url)
        data_json = json.loads(response.read())
        embedded = data_json["_embedded"]
        tb= embedded[vtabelasiasg]
        num=data_json["count"]
        df = pd.DataFrame.from_dict(tb, orient='columns')
        if '_links' in df.columns:
            del df['_links']
        df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate) 
        if createindex:
            sqlEngine.execute(chavetabela)
            createindex = False 
    except HTTPError as e:
        print(e.code)
        print(e.read())       
    pag += 1
    print(pag)
numpag=num // 500
resto = num % 500
if(resto > 0):
    numpag = numpag+1
print(numpag)

# %% [markdown]
# # CNAES

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import datetime
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
import pandas as pd2
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
vtabela = 'cnaes'
vtabelasiasg= 'cnaes'
url = 'http://compras.dados.gov.br/fornecedores/v1/cnaes.json'
vlink = 'http://compras.dados.gov.br/fornecedores/v1/cnaes.json?offset='
chavetabela = 'alter table cnaes add primary key (id)'
createindex= False

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)

    
responserdc = urlopen(url)
data_json = json.loads(responserdc.read())
num=data_json["count"]
embedded = data_json["_embedded"]
fornec= embedded[vtabelasiasg]
# Mostra número de uasgs e número de páginas
print(num)
numpag = num // 500
print(numpag)
pag = 0
while pag<=numpag:
    print(pag)
    valpag=500*pag
    url = vlink+str(valpag)
    try:
        response = urlopen(url)
        data_json = json.loads(response.read())
        embedded = data_json["_embedded"]
        tb= embedded[vtabelasiasg]
        num=data_json["count"]
        df = pd.DataFrame.from_dict(tb, orient='columns')
        if '_links' in df.columns:
            del df['_links']
        df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate) 
        if createindex:
            sqlEngine.execute(chavetabela)
            createindex = False
    except HTTPError as e:
        print(e.code)
        print(e.read())       
    pag += 1
numpag=num // 500
resto = num % 500
if(resto > 0):
    numpag = numpag+1
print(numpag)

# %% [markdown]
# # Âmbitos de ocorrência

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import datetime
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
import pandas as pd2
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
vtabela = 'ambitos_ocorrencia'
vtabelasiasg= 'AmbitosOcorrencia'
url = 'http://compras.dados.gov.br/fornecedores/v1/ambitos_ocorrencia.json'
vlink = 'http://compras.dados.gov.br/fornecedores/v1/ambitos_ocorrencia.json?offset='
chavetabela = 'alter table ambitos_ocorrencia add primary key (id)'
createindex= False

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)
    
responserdc = urlopen(url)
data_json = json.loads(responserdc.read())
num=data_json["count"]
# Mostra número de registros e número de páginas
print(num)
numpag = num // 500
print(numpag)
pag = 0
while pag<=numpag:
    print(pag)
    valpag=500*pag
    url = vlink+str(valpag)
    try:
        response = urlopen(url)
        data_json = json.loads(response.read())
        embedded = data_json["_embedded"]
        tb= embedded[vtabelasiasg]
        num=data_json["count"]
        df = pd.DataFrame.from_dict(tb, orient='columns')
        if '_links' in df.columns:
            del df['_links']
        df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate) 
        if createindex:
            sqlEngine.execute(chavetabela)
            createindex = False
    except HTTPError as e:
        print(e.code)
        print(e.read())       
    pag += 1
numpag=num // 500
resto = num % 500
if(resto > 0):
    numpag = numpag+1
print(numpag)

# %% [markdown]
# # Linhas de fornecimento

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
vtabela = 'linhas_fornecimento'
vtabelasiasg= 'linhasFornecimento'
url = 'http://compras.dados.gov.br/fornecedores/v1/linhas_fornecimento.json'
vlink = 'http://compras.dados.gov.br/fornecedores/v1/linhas_fornecimento.json?offset='
chavetabela = 'alter table linhas_fornecimento add primary key (id)'
createindex= False

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)
    
responserdc = urlopen(url)
data_json = json.loads(responserdc.read())
num=data_json["count"]
# Mostra número de registros e número de páginas
print(num)
numpag = num // 500
print(numpag)
pag = 0
while pag<=numpag:
    print(pag)
    valpag=500*pag
    url = vlink+str(valpag)
    try:
        response = urlopen(url)
        data_json = json.loads(response.read())
        embedded = data_json["_embedded"]
        tb= embedded[vtabelasiasg]
        num=data_json["count"]
        df = pd.DataFrame.from_dict(tb, orient='columns')
        if '_links' in df.columns:
            del df['_links']
        df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate) 
        if createindex:
            sqlEngine.execute(chavetabela)
            createindex = False
    except HTTPError as e:
        print(e.code)
        print(e.read())       
    pag += 1
numpag=num // 500
resto = num % 500
if(resto > 0):
    numpag = numpag+1
print(numpag)

# %% [markdown]
# # Municípios

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
vtabela = 'municipios'
vtabelasiasg= 'municipios'
url = 'http://compras.dados.gov.br/fornecedores/v1/municipios.json'
vlink = 'http://compras.dados.gov.br/fornecedores/v1/municipios.json?offset='
chavetabela = 'alter table municipios add primary key (id)'
createindex= False

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)
    
responserdc = urlopen(url)
data_json = json.loads(responserdc.read())
num=data_json["count"]
# Mostra número de registros e número de páginas
print(num)
numpag = num // 500
print(numpag)
pag = 0
while pag<=numpag:
    print(pag)
    valpag=500*pag
    url = vlink+str(valpag)
    try:
        response = urlopen(url)
        data_json = json.loads(response.read())
        embedded = data_json["_embedded"]
        tb= embedded[vtabelasiasg]
        num=data_json["count"]
        df = pd.DataFrame.from_dict(tb, orient='columns')
        if '_links' in df.columns:
            del df['_links']
        df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate) 
        if createindex:
            sqlEngine.execute(chavetabela)
            createindex = False
    except HTTPError as e:
        print(e.code)
        print(e.read())       
    pag += 1
numpag=num // 500
resto = num % 500
if(resto > 0):
    numpag = numpag+1
print(numpag)

# %% [markdown]
# # Naturezas Jurídicas

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
vtabela = 'naturezas_juridicas'
vtabelasiasg= 'naturezasJuridicas'
url = 'http://compras.dados.gov.br/fornecedores/v1/naturezas_juridicas.json'
vlink = 'http://compras.dados.gov.br/fornecedores/v1/naturezas_juridicas.json?descricao=i'
chavetabela = 'alter table naturezas_juridicas add primary key (id)'

createindex= False

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)
    
    
responserdc = urlopen(vlink)
data_json = json.loads(responserdc.read())
num=data_json["count"]
# Mostra número de registros e número de páginas
print(num)
numpag = num // 500
print(numpag)
pag = 0
while pag<=numpag:
    print(pag)
    valpag=500*pag
    url = vlink+str(valpag)
    try:
        response = urlopen(url)
        data_json = json.loads(response.read())
        embedded = data_json["_embedded"]
        tb= embedded[vtabelasiasg]
        num=data_json["count"]
        df = pd.DataFrame.from_dict(tb, orient='columns')
        if '_links' in df.columns:
            del df['_links']
        df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate) 
        if createindex:
            sqlEngine.execute(chavetabela)
            createindex = False
    except HTTPError as e:
        print(e.code)
        print(e.read())       
    pag += 1
numpag=num // 500
resto = num % 500
if(resto > 0):
    numpag = numpag+1
print(numpag)

# %% [markdown]
# # Ocorrências dos fornecedores

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
vtabela = 'ocorrencias_fornecedores'
vtabelasiasg= 'ocorrenciasFornecedores'
vlink = 'http://compras.dados.gov.br/fornecedores/v1/ocorrencias_fornecedores.json?offset='
url = 'http://compras.dados.gov.br/fornecedores/v1/ocorrencias_fornecedores.json'
chavetabela = 'alter table ocorrencias_fornecedores add primary key (id)'
createindex= False

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)
    
responserdc = urlopen(url)
data_json = json.loads(responserdc.read())
num=data_json["count"]
# Mostra número de registros e número de páginas
print(num)
numpag = num // 500
print(numpag)
pag = 0
while pag<=numpag:
    print(pag)
    valpag=500*pag
    url = vlink+str(valpag)
    try:
        response = urlopen(url)
        data_json = json.loads(response.read())
        embedded = data_json["_embedded"]
        tb= embedded[vtabelasiasg]
        num=data_json["count"]
        df = pd.DataFrame.from_dict(tb, orient='columns')
        if '_links' in df.columns:
            del df['_links']
        df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate) 
        if createindex:
            sqlEngine.execute(chavetabela)
            createindex = False
    except HTTPError as e:
        print(e.code)
        print(e.read())       
    pag += 1
numpag=num // 500
resto = num % 500
if(resto > 0):
    numpag = numpag+1
print(numpag)

# %% [markdown]
# # Portes de Empresas

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
vtabela = 'portes_empresa'
vtabelasiasg= 'portesEmpresa'
url = 'http://compras.dados.gov.br/fornecedores/v1/portes_empresa.json'
vlink = 'http://compras.dados.gov.br/fornecedores/v1/portes_empresa.json?offset='
chavetabela = 'alter table portes_empresa add primary key (id)'
createindex= False

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)
    
responserdc = urlopen(url)
data_json = json.loads(responserdc.read())
num=data_json["count"]
# Mostra número de registros e número de páginas
print(num)
numpag = num // 500
print(numpag)
pag = 0
while pag<=numpag:
    print(pag)
    valpag=500*pag
    url = vlink+str(valpag)
    try:
        response = urlopen(url)
        data_json = json.loads(response.read())
        embedded = data_json["_embedded"]
        tb= embedded[vtabelasiasg]
        num=data_json["count"]
        df = pd.DataFrame.from_dict(tb, orient='columns')
        if '_links' in df.columns:
            del df['_links']
        df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate) 
        if createindex:
            sqlEngine.execute(chavetabela)
            createindex = False
    except HTTPError as e:
        print(e.code)
        print(e.read())       
    pag += 1
numpag=num // 500
resto = num % 500
if(resto > 0):
    numpag = numpag+1
print(numpag)

# %% [markdown]
# # Prazos de Ocorrência

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
vtabela = 'prazos_ocorrencia'
vtabelasiasg= 'PrazosOcorrencia'
url = 'http://compras.dados.gov.br/fornecedores/v1/prazos_ocorrencia.json'
vlink = 'http://compras.dados.gov.br/fornecedores/v1/prazos_ocorrencia.json?offset='
chavetabela = 'alter table portes_empresa add primary key (id)'
createindex= False

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)
    
responserdc = urlopen(url)
data_json = json.loads(responserdc.read())
num=data_json["count"]
# Mostra número de registros e número de páginas
print(num)
numpag = num // 500
print(numpag)
pag = 0
while pag<=numpag:
    print(pag)
    valpag=500*pag
    url = vlink+str(valpag)
    try:
        response = urlopen(url)
        data_json = json.loads(response.read())
        embedded = data_json["_embedded"]
        tb= embedded[vtabelasiasg]
        num=data_json["count"]
        df = pd.DataFrame.from_dict(tb, orient='columns')
        if '_links' in df.columns:
            del df['_links']
        df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate) 
        if createindex:
            sqlEngine.execute(chavetabela)
            createindex = False
    except HTTPError as e:
        print(e.code)
        print(e.read())       
    pag += 1
numpag=num // 500
resto = num % 500
if(resto > 0):
    numpag = numpag+1
print(numpag)

# %% [markdown]
# # Ramos de negócio

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
vtabela = 'ramos_negocio'
vtabelasiasg= 'ramosNegocio'
url = 'http://compras.dados.gov.br/fornecedores/v1/ramos_negocio.json'
vlink = 'http://compras.dados.gov.br/fornecedores/v1/ramos_negocio.json?offset='
chavetabela = 'alter table portes_empresa add primary key (id)'
createindex= False

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)
    
responserdc = urlopen(url)
data_json = json.loads(responserdc.read())
num=data_json["count"]
# Mostra número de registros e número de páginas
print(num)
numpag = num // 500
print(numpag)
pag = 0
while pag<=numpag:
    print(pag)
    valpag=500*pag
    url = vlink+str(valpag)
    try:
        response = urlopen(url)
        data_json = json.loads(response.read())
        embedded = data_json["_embedded"]
        tb= embedded[vtabelasiasg]
        num=data_json["count"]
        df = pd.DataFrame.from_dict(tb, orient='columns')
        if '_links' in df.columns:
            del df['_links']
        df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate) 
        if createindex:
            sqlEngine.execute(chavetabela)
            createindex = False
    except HTTPError as e:
        print(e.code)
        print(e.read())       
    pag += 1
numpag=num // 500
resto = num % 500
if(resto > 0):
    numpag = numpag+1
print(numpag)

# %% [markdown]
# # Tipos de Ocorrência

# %%
from sqlalchemy import create_engine
from urllib.request import urlopen
from urllib.error import URLError, HTTPError
import pymysql
import json
from sqlalchemy.dialects.mysql import insert
import pandas as pd
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
vtabela = 'tipos_ocorrencia'
vtabelasiasg= 'tiposOcorrencia'
url = 'http://compras.dados.gov.br/fornecedores/v1/tipos_ocorrencia.json' 
vlink = 'http://compras.dados.gov.br/fornecedores/v1/tipos_ocorrencia.json?offset='
chavetabela = 'alter table portes_empresa add primary key (id)'
createindex= False

def insert_on_duplicate(table, conn, keys, data_iter):
    insert_stmt = insert(table.table).values(list(data_iter))
    on_duplicate_key_stmt = insert_stmt.on_duplicate_key_update(insert_stmt.inserted)
    conn.execute(on_duplicate_key_stmt)
    
responserdc = urlopen(url)
data_json = json.loads(responserdc.read())
num=data_json["count"]
# Mostra número de registros e número de páginas
print(num)
numpag = num // 500
print(numpag)
pag = 0
while pag<=numpag:
    print(pag)
    valpag=500*pag
    url = vlink+str(valpag)
    try:
        response = urlopen(url)
        data_json = json.loads(response.read())
        embedded = data_json["_embedded"]
        tb= embedded[vtabelasiasg]
        num=data_json["count"]
        df = pd.DataFrame.from_dict(tb, orient='columns')
        if '_links' in df.columns:
            del df['_links']
        df.to_sql(vtabela, sqlEngine, if_exists='append', index=False, method=insert_on_duplicate) 
        if createindex:
            sqlEngine.execute(chavetabela)
            createindex = False
    except HTTPError as e:
        print(e.code)
        print(e.read())       
    pag += 1
numpag=num // 500
resto = num % 500
if(resto > 0):
    numpag = numpag+1
print(numpag)

# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
fornecedores = pd.read_sql("SELECT count(*) as numfornecedores from siasg.fornecedores", dbConnection);
municipios = pd.read_sql("SELECT count(*) as nummunicipios from siasg.municipios", dbConnection);
print('Total de dados de fornecedores recuperados= '+str(fornecedores.iloc[0,0]))
print('Total de dados de municípios recuperados= '+str(municipios.iloc[0,0]))
