# %% [markdown]
# # COPOD nos 10 primeiros
# Teste do SUOD  para comparação e seleção dos integrantes do aplicativo

# %%
import numpy as np
import pandas as pd
import os
from sklearn.metrics import accuracy_score,recall_score
from pyod.utils.data import evaluate_print
import time

# Importa bibliotecas do PyOD com os algoritmos de detecção de anomalias
from pyod.models.inne import INNE
from pyod.models.abod import ABOD
from pyod.models.cblof import CBLOF
from pyod.models.knn import KNN
from pyod.models.lof import LOF
from pyod.models.pca import PCA
from pyod.models.sampling import Sampling
from pyod.models.ecod import ECOD
from pyod.models.copod import COPOD
from pyod.models.suod import SUOD
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score

tabelafinal = pd.DataFrame(columns=['material','acuracia','recall','tempo'])
print(tabelafinal)
      
def carrega_material(path,material):
    arquivo = str(material)+".csv"
    csv_path = os.path.join(path,arquivo)
    df = pd.read_csv(csv_path)
    ## Retira os campos que não serão utilizados no treinamento
    df = df.drop(['licitacao_contrato'],axis=1)
    df = df.drop(['id'],axis=1)
    df = df.drop(['data'],axis=1)
    df = df.drop(['catmat_id'],axis=1)
    df = df.drop(['unidade'],axis=1)
    df = df.drop(['valor_total'],axis=1)
    df = df.drop(['municipio_uasg'],axis=1)
    df = df.drop(['municipio_fornecedor'],axis=1)
    return df
# Out:
# Empty DataFrame
# Columns: [material, acuracia, recall, tempo]
# Index: []

# %%
from sqlalchemy import create_engine
import pymysql
from sqlalchemy.dialects.mysql import insert
import pandas as pd
sqlEngine       = create_engine('mysql+pymysql://siasg:siasg@192.168.2.135/siasg', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
itens = pd.read_sql("SELECT * from siasg.itens", dbConnection);

maioresitens = pd.read_sql("SELECT catmat_id, count(*) from siasg.itens where valor_unitario>0 and catmat_id!=0 group by catmat_id order by count(*) desc", dbConnection);

# %% [markdown]
# # Recuperação dos dados a serem utilizados na avaliação

# %%
##Carrega os dados do item
for index, row in maioresitens.iterrows():
    iniciomaterial = time.time()
    catmat = row['catmat_id']
    df=carrega_material(".",catmat)  
    print(catmat)
    # Separação do Label dos dados
    x = df.iloc[:, :-1]
    y = df.iloc[:, -1]
    #if index<2:
    #    continue
    detector_list = [
             INNE(contamination=0.05, n_estimators=50, random_state= 69), 
             ABOD(contamination=0.05, method= 'default', n_neighbors=20),
             CBLOF(contamination=0.05, n_clusters=2),
             KNN(contamination=0.05, leaf_size=10, method='largest', n_neighbors=10),
             LOF(contamination=0.05, leaf_size=1, n_neighbors=34),  
             PCA(contamination=0.05, n_components=3, n_selected_components=1),
             Sampling(contamination=0.05, subset_size=10),
             ECOD(contamination=0.09),
             COPOD(contamination=0.12)
    ]

    # Inicializar o modelo SUOD
    model = COPOD(contamination=0.12)

    # Definir a validação cruzada estratificada
    cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=69)

    acuracia=[]
    recall=[]

    # Loop para treinar e testar o modelo
    k=1
    for train_index, test_index in cv.split(x,y):
        iniciofold = time.time()
        print('iniciando treinamento '+str(k))
        X_train, X_test = x.iloc[train_index], x.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Treinar o modelo
        model.fit(X_train)

        # Fazer as previsões
        y_pred = model.predict(X_test)

        # Calcular a acurácia
        acc = accuracy_score(y_test, y_pred)
        print(f'Acurácia: {acc}')
        acuracia.append(acc)

        # Calcular o Recall
        rec = recall_score(y_test, y_pred)
        print(f'Recall: {rec}')
        recall.append(rec)
        fimfold = time.time()
        tempofold = fimfold-iniciofold
        print(tempofold)
        k+=1

    acuracia_media = sum(acuracia) / len(acuracia)
    recall_medio = sum(recall) / len(recall)


    print(f'Acurácia média: {acuracia_media}')
    print(f'Recall médio: {recall_medio}')
    fim = time.time()
    tempo = fim-iniciomaterial
    print(tempo)
    
    # Grava os resultados da avaliação na tabela final
    tabelafinal.loc[len(tabelafinal.index)] = [catmat,acuracia_media,recall_medio,tempo] 
    if index==9:
        break
# Out:
# 104671
# iniciando treinamento 1
# Acurácia: 0.9027426160337553
# Recall: 0.9915966386554622
# 0.3996872901916504
# iniciando treinamento 2
# Acurácia: 0.909915611814346
# Recall: 0.9915966386554622
# 0.07813620567321777
# iniciando treinamento 3
# Acurácia: 0.8959915611814346
# Recall: 1.0
# 0.07899928092956543
# iniciando treinamento 4
# Acurácia: 0.9103375527426161
# Recall: 1.0
# 0.09085631370544434
# iniciando treinamento 5
# Acurácia: 0.9039881831610044
# Recall: 1.0
# 0.07628417015075684
# iniciando treinamento 6
# Acurácia: 0.8980797636632201
# Recall: 1.0
# 0.07854080200195312
# iniciando treinamento 7
# Acurácia: 0.9079974678202153
# Recall: 1.0
# 0.07728123664855957
# iniciando treinamento 8
# Acurácia: 0.9086305127664064
# Recall: 1.0
# 0.07526588439941406
# iniciando treinamento 9
# Acurácia: 0.9046212281071956
# Recall: 1.0
# 0.05847644805908203
# iniciando treinamento 10
# Acurácia: 0.9071534078919603
# Recall: 1.0
# 0.08605623245239258
# Acurácia média: 0.9049457905182156
# Recall médio: 0.9983193277310924
# 1.1541943550109863
# 150658
# iniciando treinamento 1
# Acurácia: 0.8977599080987938
# Recall: 1.0
# 0.016649723052978516
# iniciando treinamento 2
# Acurácia: 0.8948879954049397
# Recall: 1.0
# 0.03074502944946289
# iniciando treinamento 3
# Acurácia: 0.9069500287191269
# Recall: 1.0
# 0.035834312438964844
# iniciando treinamento 4
# Acurácia: 0.9115450890292935
# Recall: 1.0
# 0.03327631950378418
# iniciando treinamento 5
# Acurácia: 0.919586444572085
# Recall: 1.0
# 0.01651453971862793
# iniciando treinamento 6
# Acurácia: 0.9023549684089603
# Recall: 1.0
# 0.03337717056274414
# iniciando treinamento 7
# Acurácia: 0.9172889144170018
# Recall: 1.0
# 0.027996540069580078
# iniciando treinamento 8
# Acurácia: 0.8960367604824814
# Recall: 1.0
# 0.023934364318847656
# iniciando treinamento 9
# Acurácia: 0.9006318207926479
# Recall: 1.0
# 0.032921552658081055
# iniciando treinamento 10
# Acurácia: 0.9022988505747126
# Recall: 1.0
# 0.015091419219970703
# Acurácia média: 0.9049340780500043
# Recall médio: 1.0
# 0.2814981937408447
# 445485
# iniciando treinamento 1
# Acurácia: 0.92
# Recall: 1.0
# 0.0
# iniciando treinamento 2
# Acurácia: 0.918918918918919
# Recall: 1.0
# 0.0
# iniciando treinamento 3
# Acurácia: 0.8513513513513513
# Recall: 1.0
# 0.0
# iniciando treinamento 4
# Acurácia: 0.8513513513513513
# Recall: 1.0
# 0.015748262405395508
# iniciando treinamento 5
# Acurácia: 0.9054054054054054
# Recall: 1.0
# 0.0
# iniciando treinamento 6
# Acurácia: 0.9459459459459459
# Recall: 1.0
# 0.0
# iniciando treinamento 7
# Acurácia: 0.918918918918919
# Recall: 1.0
# 0.015521526336669922
# iniciando treinamento 8
# Acurácia: 0.918918918918919
# Recall: 1.0
# 0.0
# iniciando treinamento 9
# Acurácia: 0.918918918918919
# Recall: 1.0
# 0.0
# iniciando treinamento 10
# Acurácia: 0.918918918918919
# Recall: 1.0
# 0.015712261199951172
# Acurácia média: 0.906864864864865
# Recall médio: 1.0
# 0.0509951114654541
# 402920
# iniciando treinamento 1
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 2
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 3
# Acurácia: 0.7209302325581395
# Recall: 1.0
# 0.015531301498413086
# iniciando treinamento 4
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 5
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 6
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 7
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 8
# Acurácia: 0.7441860465116279
# Recall: 1.0
# 0.015624284744262695
# iniciando treinamento 9
# Acurácia: 0.7441860465116279
# Recall: 1.0
# 0.007337331771850586
# iniciando treinamento 10
# Acurácia: 0.7209302325581395
# Recall: 1.0
# 0.0
# Acurácia média: 0.8930232558139533
# Recall médio: 1.0
# 0.03849291801452637
# 150877
# iniciando treinamento 1
# Acurácia: 0.9230769230769231
# Recall: 1.0
# 0.0
# iniciando treinamento 2
# Acurácia: 0.8205128205128205
# Recall: 1.0
# 0.006007671356201172
# iniciando treinamento 3
# Acurácia: 0.8974358974358975
# Recall: 1.0
# 0.0
# iniciando treinamento 4
# Acurácia: 0.9743589743589743
# Recall: 1.0
# 0.0
# iniciando treinamento 5
# Acurácia: 0.8947368421052632
# Recall: 0.0
# 0.01000666618347168
# iniciando treinamento 6
# Acurácia: 0.9473684210526315
# Recall: 1.0
# 0.0
# iniciando treinamento 7
# Acurácia: 0.8947368421052632
# Recall: 1.0
# 0.0
# iniciando treinamento 8
# Acurácia: 0.9210526315789473
# Recall: 1.0
# 0.0
# iniciando treinamento 9
# Acurácia: 0.9473684210526315
# Recall: 1.0
# 0.0
# iniciando treinamento 10
# Acurácia: 0.7894736842105263
# Recall: 1.0
# 0.01563405990600586
# Acurácia média: 0.9010121457489879
# Recall médio: 0.9
# 0.040155887603759766
# 481567
# iniciando treinamento 1
# Acurácia: 0.8888888888888888
# Recall: 1.0
# 0.0
# iniciando treinamento 2
# Acurácia: 0.7777777777777778
# Recall: 1.0
# 0.0
# iniciando treinamento 3
# Acurácia: 0.8611111111111112
# Recall: 1.0
# 0.0
# iniciando treinamento 4
# Acurácia: 0.9444444444444444
# Recall: 1.0
# 0.020331859588623047
# iniciando treinamento 5
# Acurácia: 0.9444444444444444
# Recall: 1.0
# 0.004344940185546875
# iniciando treinamento 6
# Acurácia: 0.9444444444444444
# Recall: 1.0
# 0.0050089359283447266
# iniciando treinamento 7
# Acurácia: 0.9722222222222222
# Recall: 1.0
# 0.0
# iniciando treinamento 8
# Acurácia: 0.9142857142857143
# Recall: 1.0
# 0.0
# iniciando treinamento 9
# Acurácia: 0.9142857142857143
# Recall: 1.0
# 0.011734724044799805
# iniciando treinamento 10
# Acurácia: 0.9428571428571428
# Recall: 1.0
# 0.0
# Acurácia média: 0.9104761904761907
# Recall médio: 1.0
# 0.04142045974731445
# 460872
# iniciando treinamento 1
# Acurácia: 0.8857142857142857
# Recall: 1.0
# 0.0
# iniciando treinamento 2
# Acurácia: 0.9714285714285714
# Recall: 1.0
# 0.01676177978515625
# iniciando treinamento 3
# Acurácia: 0.9428571428571428
# Recall: 1.0
# 0.004227638244628906
# iniciando treinamento 4
# Acurácia: 1.0
# Recall: 1.0
# 0.003008127212524414
# iniciando treinamento 5
# Acurácia: 0.9714285714285714
# Recall: 1.0
# 0.0030126571655273438
# iniciando treinamento 6
# Acurácia: 0.8571428571428571
# Recall: 1.0
# 0.0029861927032470703
# iniciando treinamento 7
# Acurácia: 0.9714285714285714
# Recall: 1.0
# 0.003260374069213867
# iniciando treinamento 8
# Acurácia: 0.8823529411764706
# Recall: 1.0
# 0.003126382827758789
# iniciando treinamento 9
# Acurácia: 0.9705882352941176
# Recall: 1.0
# 0.003009319305419922
# iniciando treinamento 10
# Acurácia: 0.8823529411764706
# Recall: 1.0
# 0.003915071487426758
# Acurácia média: 0.9335294117647059
# Recall médio: 1.0
# 0.04330754280090332
# 469793
# iniciando treinamento 1
# Acurácia: 0.07142857142857142
# Recall: 1.0
# 0.003097057342529297
# iniciando treinamento 2
# Acurácia: 0.07142857142857142
# Recall: 1.0
# 0.0
# iniciando treinamento 3
# Acurácia: 0.07142857142857142
# Recall: 1.0
# 0.0
# iniciando treinamento 4
# Acurácia: 0.03571428571428571
# Recall: 1.0
# 0.0
# iniciando treinamento 5
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 6
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 7
# Acurácia: 1.0
# Recall: 1.0
# 0.015756607055664062
# iniciando treinamento 8
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 9
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 10
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# Acurácia média: 0.625
# Recall médio: 1.0
# 0.02284526824951172
# 461652
# iniciando treinamento 1
# Acurácia: 0.8095238095238095
# Recall: 0.0
# 0.015622377395629883
# iniciando treinamento 2
# Acurácia: 0.8571428571428571
# Recall: 0.0
# 0.0
# iniciando treinamento 3
# Acurácia: 0.8571428571428571
# Recall: 0.0
# 0.0
# iniciando treinamento 4
# Acurácia: 0.9523809523809523
# Recall: 0.0
# 0.01563119888305664
# iniciando treinamento 5
# Acurácia: 0.9523809523809523
# Recall: 1.0
# 0.0
# iniciando treinamento 6
# Acurácia: 0.9047619047619048
# Recall: 1.0
# 0.0
# iniciando treinamento 7
# Acurácia: 0.9047619047619048
# Recall: 1.0
# 0.0
# iniciando treinamento 8
# Acurácia: 0.9523809523809523
# Recall: 1.0
# 0.0
# iniciando treinamento 9
# Acurácia: 0.8571428571428571
# Recall: 1.0
# 0.016685962677001953
# iniciando treinamento 10
# Acurácia: 1.0
# Recall: 0.0
# 0.002500772476196289
# Acurácia média: 0.9047619047619049
# Recall médio: 0.5
# 0.050440311431884766
# 464381
# iniciando treinamento 1
# Acurácia: 1.0
# Recall: 1.0
# 0.0
# iniciando treinamento 2
# Acurácia: 0.8571428571428571
# Recall: 1.0
# 0.0
# iniciando treinamento 3
# Acurácia: 0.9523809523809523
# Recall: 1.0
# 0.0
# iniciando treinamento 4
# Acurácia: 0.8571428571428571
# Recall: 1.0
# 0.01623392105102539
# iniciando treinamento 5
# Acurácia: 0.8571428571428571
# Recall: 1.0
# 0.005254030227661133
# iniciando treinamento 6
# Acurácia: 0.75
# Recall: 0.0
# 0.0
# iniciando treinamento 7
# Acurácia: 0.95
# Recall: 0.0
# 0.0
# iniciando treinamento 8
# Acurácia: 1.0
# Recall: 0.0
# 0.010113716125488281
# iniciando treinamento 9
# Acurácia: 1.0
# Recall: 0.0
# 0.0
# iniciando treinamento 10
# Acurácia: 0.9
# Recall: 1.0
# 0.0
# Acurácia média: 0.9123809523809525
# Recall médio: 0.6
# 0.031601667404174805

# %% [markdown]
# # Imprime a tabela final de avaliação

# %%
tabelafinal.sort_values("recall", axis = 0, ascending = False,
                 inplace = True, na_position ='last')
print(tabelafinal)
# Out:
#    material  acuracia    recall     tempo
# 1  150658.0  0.904934  1.000000  0.281498
# 2  445485.0  0.906865  1.000000  0.050995
# 3  402920.0  0.893023  1.000000  0.038493
# 5  481567.0  0.910476  1.000000  0.041420
# 6  460872.0  0.933529  1.000000  0.043308
# 7  469793.0  0.625000  1.000000  0.022845
# 0  104671.0  0.904946  0.998319  1.154194
# 4  150877.0  0.901012  0.900000  0.040156
# 9  464381.0  0.912381  0.600000  0.031602
# 8  461652.0  0.904762  0.500000  0.050440
